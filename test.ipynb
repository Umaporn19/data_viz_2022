# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import panda เพื่อจัดการตาราง
import os

# %%
from google.colab import drive #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
drive.mount('/content/drive') 
path = '/content/drive/My Drive/data_jknow' #เชื่อมกับไดร์ฟ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์'
# /content

# %%
data_file_path = os.path.join(path,'shopee.xlsx') 
data = pd.read_excel(data_file_path)

# %%
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                       object
# สถานะการสั่งซื้อ                        object
# เหตุผลในการยกเลิกคำสั่งซื้อ             object
# สถานะการคืนเงินหรือคืนสินค้า            object
# ชื่อผู้ใช้ (ผู้ซื้อ)                    object
# วันที่ทำการสั่งซื้อ                     object
# เวลาการชำระสินค้า                       object
# ช่องทางการชำระเงิน                      object
# ช่องทางการชำระเงิน (รายละเอียด)_1      float64
# ช่องทางการชำระเงิน (รายละเอียด)_2       object
# ค่าธรรมเนียม (%)                        object
# ตัวเลือกการจัดส่ง                       object
# วิธีการจัดส่ง                           object
# *หมายเลขติดตามพัสดุ                     object
# วันที่คาดว่าจะทำการจัดส่งสินค้า         object
# เวลาส่งสินค้า                           object
# เลขอ้างอิง Parent SKU                  float64
# ชื่อสินค้า                              object
# เลขอ้างอิง SKU (SKU Reference No.)     float64
# ชื่อตัวเลือก                            object
# ...

# %%
from datetime import datetime

# %%
data['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(data['วันที่ทำการสั่งซื้อ'],format="%Y-%m-%d") 
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                   object
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                              object
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                               object
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                            object
# วันที่คาดว่าจะทำการจัดส่งสินค้า                object
# เวลาส่งสินค้า                                  object
# เลขอ้างอิง Parent SKU                         float64
# ...

# %%
data['เวลาการชำระสินค้า'] = pd.to_datetime(data['เวลาการชำระสินค้า'],format="%Y-%m-%d",errors='coerce')
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(data['เวลาที่ทำการสั่งซื้อสำเร็จ'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data['วันที่คาดว่าจะทำการจัดส่งสินค้า'] = pd.to_datetime(data['วันที่คาดว่าจะทำการจัดส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data['เวลาส่งสินค้า'] = pd.to_datetime(data['เวลาส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                   object
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                      datetime64[ns]
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                               object
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                            object
# วันที่คาดว่าจะทำการจัดส่งสินค้า        datetime64[ns]
# เวลาส่งสินค้า                          datetime64[ns]
# เลขอ้างอิง Parent SKU                         float64
# ...

# %%
set(data['ชื่อสินค้า'])
# Out:
# {'AFFNL (ใส่โค้ดลดเพิ่ม 25%) E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.',
#  'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม',
# ...

# %%
data['ชื่อสินค้า'].replace ({'AFFNL (ใส่โค้ดลดเพิ่ม 25%) E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15':'หนังสือสมรรถนะ มข',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.':'หนังสือสรุปม.ปลาย Tcas',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัด':'หนังสือเตรียมสอบครู',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบวิศวกรรมศาสตร์  รวมข้อสอบจริงและเฉลย ฟรี! คอรสติวเตรียมสอบความถนัดวิศวะ PAT 3':'หนังสือเตรียมสอบวิศวะ',
'AFFNL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบเข้าคณะมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
'E-Book ติวสอบท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล ปฏิบัติการ >>ไฟล์ E-Book<<':'E-Book เตรียมสอบ ท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
'E-Book หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
'E-Book หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชม.':'E-Book เตรียมสอบครู',
'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65':'E-Book เตรียมสอบ Netsat',
'E-Book เตรียมสอบสายแพทย์วิทย์สุขภาพ ฟรี! คอร์สติวเตรียมสายแพทย์ 16 ชม.':'E-Book สายแพทย์-วิทย์สุขภาพ',
'E-book สรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรี คอร์สสรุปเนื้อหาม.ปลาย 25 ชม.':'E-book สรุปเนื้อหา ม.ปลาย',
'E-book หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม. [ส่งฟรีไม่ง้อโค้ด]':'E-book สรุปเนื้อหา ม.ปลาย',
'E-book เตรียมสอบวิศวกรรมศาสตร์ ฟรี คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'E-Book เตรียมสอบวิศวะ',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.':'หนังสือเตรียมสอบ ก.พ.',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 5 ชม.':'หนังสือเตรียมสอบ ก.พ.',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15':'หนังสือสมรรถนะ มข',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.':'หนังสือสรุปม.ปลาย Tcas',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'หนังสือเตรียมสอบ Netsat',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม':'หนังสือแพทย์-ทันตะ',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัด':'หนังสือเตรียมสอบครู',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบวิศวกรรมศาสตร์  รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT':'หนังสือเตรียมสอบวิศวะ',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบสายแพทย์วิทย์สุขภาพ ฟรี! คอร์สติวเตรียมสายแพทย์ 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'SSPJKL (ใส่โค้ดลดเพิ่ม 25%) หนังสือเตรียมสอบเข้าคณะมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
'คอร์สติวเร่งรัดสอบผ่าน ก.พ. 64-65 จำนวน 40 ชั่วโมง ฟรี E-book ติวเตรียมสอบ ก.พ. 64-65':'หนังสือเตรียมสอบ ก.พ.',
'คอร์สติวเร่งรัดสอบผ่าน ก.พ. 64-65 จำนวน 40 ชั่วโมง ฟรีหนังสือติวสอบ ก.พ. 64-65':'หนังสือเตรียมสอบ ก.พ.',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญคณิตศาสตร์':'หนังสือสามัญ คณิตศาสตร์',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญชีววิทยา':'หนังสือสามัญ ชีววิทยา',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญทุกวิชาที่ใช้สอบ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญฟิสิกส์':'หนังสือสามัญ ฟิสิกส์',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญภาษาอังกฤษ':'หนังสือสามัญ ภาษาอังกฤษ',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญภาษาไทย + สังคม':'หนังสือสามัญ ภาษาไทย + สังคม',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญเคมี':'หนังสือสามัญ เคมี',
'หนังสือ ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 5 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'หนังสือติวสอบท้องถิ่น ภาค ก และเฉลยข้อสอบจริงท้องถิ่น (ภาค ก) 64 ฟรี! คอร์สติว 35 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'หนังสือติวสอบท้องถิ่น ภาค ก และเฉลยข้อสอบจริงท้องถิ่น (ภาค ก) 64 ฟรี! วิดีโอติว 35 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก',
'หนังสือติวสอบท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
'หนังสือติวสอบท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
'หนังสือติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 + วิดีโอติว 40 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'หนังสือติวและเฉลยข้อสอบจริง ท้องถิ่น (ภาค ก) 64 + วิดีโอติว 35 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
'หนังสือท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง)':'หนังสือสมรรถนะ มข',
'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15':'หนังสือสมรรถนะ มข',
'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15 ชม.':'หนังสือสมรรถนะ มข',
'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท.':'หนังสือสรุปม.ปลาย Tcas',
'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.':'หนังสือสรุปม.ปลาย Tcas',
'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.[ส่งฟรีไม่ง้อโค้ด]':'หนังสือสรุปม.ปลาย Tcas',
'หนังสืออิเล็กทรอนิกส์ เตรียมสอบ สำหรับ ม.ปลาย':'E-Book สรุป ม.ปลาย',
'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 และเฉลยละเอียดทุกข้อ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี❗คอร์สติววิชาสามัญ 64 และเฉลยละเอียดทุกข้อ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี🔥คอร์สติววิชาสามัญ 64 และเฉลยละเอียดทุกข้อ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65 ฟรี! คอร์สติว 21 ชม.':'หนังสือเตรียมสอบ Netsat',
'หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือเตรียมสอบ สายแพทย์ วิทยาศาสตร์สุขภาพ':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือเตรียมสอบ สายแพทย์ วิทยาศาสตร์สุขภาพ ฟรี! คอร์สติวเตรียมสายแพทย์ 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6 ชม.':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม.':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง ..':'หนังสือเตรียมสอบครู',
'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบครู',
'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง ..':'หนังสือเตรียมสอบครู',
'หนังสือเตรียมสอบพยาบาลและเฉลย + วิดีโอติว กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
'หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์  รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์  รวมข้อสอบจริงและเฉลย ฟรี! คอรสติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์  รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบสายแพทย์วิทย์สุขภาพ ฟรี! คอร์สติวเตรียมสายแพทย์ 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือเตรียมสอบเข้าคณะมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร'},inplace=True)

# %%
data
# Out:
#      หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0       211001PFVP7NFF       สำเร็จแล้ว                         NaN
# 1       211001Q88N1WU9       สำเร็จแล้ว                         NaN
# 2       211002QHGXFKGH       สำเร็จแล้ว                         NaN
# 3       211002R5QQRQNB       สำเร็จแล้ว                         NaN
# 4       211002RMMQ9NK1       สำเร็จแล้ว                         NaN
# ...                ...              ...                         ...
# 7235    22050364T72YBE    ที่ต้องจัดส่ง                         NaN
# 7236    2205036JVCD6A6    ที่ต้องจัดส่ง                         NaN
# 7237    2205036TBGR281    ที่ต้องจัดส่ง                         NaN
# 7238    22050372GHUUQE    ที่ต้องจัดส่ง                         NaN
# 7239    220503736MW53W    ที่ต้องจัดส่ง                         NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# ...
