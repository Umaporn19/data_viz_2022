# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/shopee_October_shopee_January_xlsx.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import panda เพื่อจัดการตาราง
import os

# %%
from google.colab import drive #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
drive.mount('/content/drive') 
path = '/content/drive/My Drive/data_jknow' #เชื่อมกับไดร์ฟ
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์'
# /content

# %%
data_file_path = os.path.join(path,'shopee_October - shopee_January.xlsx') 
data = pd.read_excel(data_file_path)

# %%
data
# Out:
#                 วันที่ ยอดขายทั้งหมด (THB)  คำสั่งซื้อทั้งหมด  \
# 0     01-10-2021 00:00                   0                  0
# 1     01-10-2021 01:00                   0                  0
# 2     01-10-2021 02:00                   0                  0
# 3     01-10-2021 03:00                   0                  0
# 4     01-10-2021 04:00                   0                  0
# ...                ...                 ...                ...
# 2899  31-01-2022 19:00                   0                  0
# 2900  31-01-2022 20:00                 980                  2
# 2901  31-01-2022 21:00                 980                  2
# 2902  31-01-2022 22:00                   0                  0
# 2903  31-01-2022 23:00                 490                  1
#
#      ยอดขายเฉลี่ยต่อคำสั่งซื้อ  ยอดเข้าชม  จำนวนผู้เยี่ยมชม  \
# 0                         0.00          5                 2
# 1                         0.00         15                 3
# ...

# %%
data.dtypes
# Out:
# วันที่                                           object
# ยอดขายทั้งหมด (THB)                              object
# คำสั่งซื้อทั้งหมด                                 int64
# ยอดขายเฉลี่ยต่อคำสั่งซื้อ                        object
# ยอดเข้าชม                                         int64
# จำนวนผู้เยี่ยมชม                                  int64
# อัตราการซื้อสินค้า (จากคำสั่งซื้อที่ชำระเงิน)    object
# คำสั่งซื้อที่ยกเลิก                               int64
# ยอดขายที่ยกเลิก                                  object
# คำสั่งซื้อที่คืนเงิน/คืนสินค้า                    int64
# ยอดขายที่คืนเงิน/คืนสินค้า                        int64
# dtype: object

# %%
from datetime import datetime

# %%
data['วันที่'] = pd.to_datetime(data['วันที่'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#                 วันที่ ยอดขายทั้งหมด (THB)  คำสั่งซื้อทั้งหมด  \
# 0     01-10-2021 00:00                   0                  0
# 1     01-10-2021 01:00                   0                  0
# 2     01-10-2021 02:00                   0                  0
# 3     01-10-2021 03:00                   0                  0
# 4     01-10-2021 04:00                   0                  0
# ...                ...                 ...                ...
# 2899  31-01-2022 19:00                   0                  0
# 2900  31-01-2022 20:00                 980                  2
# 2901  31-01-2022 21:00                 980                  2
# 2902  31-01-2022 22:00                   0                  0
# 2903  31-01-2022 23:00                 490                  1
#
#      ยอดขายเฉลี่ยต่อคำสั่งซื้อ  ยอดเข้าชม  จำนวนผู้เยี่ยมชม  \
# 0                         0.00          5                 2
# 1                         0.00         15                 3
# ...

# %%
data.dtypes
# Out:
# วันที่                                           object
# ยอดขายทั้งหมด (THB)                              object
# คำสั่งซื้อทั้งหมด                                 int64
# ยอดขายเฉลี่ยต่อคำสั่งซื้อ                        object
# ยอดเข้าชม                                         int64
# จำนวนผู้เยี่ยมชม                                  int64
# อัตราการซื้อสินค้า (จากคำสั่งซื้อที่ชำระเงิน)    object
# คำสั่งซื้อที่ยกเลิก                               int64
# ยอดขายที่ยกเลิก                                  object
# คำสั่งซื้อที่คืนเงิน/คืนสินค้า                    int64
# ยอดขายที่คืนเงิน/คืนสินค้า                        int64
# dtype: object

# %%
data.to_excel('shopee_October - shopee_January.xlsx', encoding='utf-8')
