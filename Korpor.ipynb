# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/Korpor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
path = '/content/drive/My Drive/Jknow'

# %%
data_file_path = os.path.join(path,'Line_All.xlsx')  
line = pd.read_excel(data_file_path)

# %% [markdown]
# # **Line**

# %%
line
# Out:
#          #  เลขรายการสั่งซื้อ ช่องทางการขาย      สร้างเมื่อ  \
# 0        1   2021100912646364    Storefront  20211009 12:37
# 1        2   2021100912646339    Storefront  20211009 12:37
# 2        3   2021100912656389    Storefront  20211009 16:30
# 3        4   2021100912656817    Storefront  20211009 16:38
# 4        5   2021100912658479    Storefront  20211009 17:19
# ...    ...                ...           ...             ...
# 1802  1803   2022050224703621    Storefront  20220502 10:31
# 1803  1804   2022050224709580    Storefront  20220502 11:58
# 1804  1805   2022010116875576    Storefront  20220101 19:18
# 1805  1806   2022050224751429    Storefront  20220503 04:44
# 1806  1807   2022050324758617    Storefront  20220503 09:53
#
#      ยืนยันการสั่งซื้อเมื่อ   ชำระเงินเมื่อ          ชื่อลูกค้า  \
# 0            20211009 12:43  20211009 13:48        SC001 หมิว ว
# 1            20211009 15:57  20211010 17:19              ตรีคูณ
# ...

# %%
from datetime import datetime

# %%
set(line['ชำระเงินเมื่อ'])
# Out:
# {'20211009 13:48',
#  '20211010 17:00',
#  '20211010 17:09',
#  '20211010 17:10',
#  '20211010 17:11',
#  '20211010 17:13',
#  '20211010 17:14',
#  '20211010 17:15',
#  '20211010 17:16',
#  '20211010 17:19',
#  '20211010 17:20',
#  '20211011 10:43',
#  '20211011 10:44',
#  '20211011 10:46',
#  '20211011 10:47',
#  '20211011 11:35',
#  '20211011 11:36',
#  '20211011 11:37',
#  '20211011 11:38',
#  '20211011 11:39',
#  '20211012 13:36',
#  '20211012 13:37',
#  '20211014 11:38',
#  '20211014 12:15',
#  '20211016 11:30',
#  '20211018 12:10',
#  '20211018 12:11',
#  '20211018 12:12',
#  '20211019 11:40',
#  '20211019 11:41',
#  '20211019 11:42',
#  '20211019 18:24',
#  '20211019 18:26',
#  '20211019 18:36',
#  '20211019 18:39',
#  '20211019 18:40',
#  '20211019 18:42',
#  '20211019 20:02',
#  '20211019 20:03',
#  '20211019 20:34',
#  '20211019 20:35',
#  '20211020 10:17',
#  '20211020 10:18',
#  '20211020 10:19',
#  '20211020 10:21',
#  '20211020 10:22',
#  '20211020 10:23',
# ...

# %%
line['สร้างเมื่อ'] = pd.to_datetime(line['สร้างเมื่อ'],errors='ignore')
line
# Out:
#          #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 0        1   2021100912646364    Storefront 2021-10-09 12:37:00
# 1        2   2021100912646339    Storefront 2021-10-09 12:37:00
# 2        3   2021100912656389    Storefront 2021-10-09 16:30:00
# 3        4   2021100912656817    Storefront 2021-10-09 16:38:00
# 4        5   2021100912658479    Storefront 2021-10-09 17:19:00
# ...    ...                ...           ...                 ...
# 1802  1803   2022050224703621    Storefront 2022-05-02 10:31:00
# 1803  1804   2022050224709580    Storefront 2022-05-02 11:58:00
# 1804  1805   2022010116875576    Storefront 2022-01-01 19:18:00
# 1805  1806   2022050224751429    Storefront 2022-05-03 04:44:00
# 1806  1807   2022050324758617    Storefront 2022-05-03 09:53:00
#
#      ยืนยันการสั่งซื้อเมื่อ   ชำระเงินเมื่อ          ชื่อลูกค้า  \
# 0            20211009 12:43  20211009 13:48        SC001 หมิว ว
# 1            20211009 15:57  20211010 17:19              ตรีคูณ
# ...

# %%
line['ยืนยันการสั่งซื้อเมื่อ'] = pd.to_datetime(line['ยืนยันการสั่งซื้อเมื่อ'],errors='ignore')

# %%
line['ชำระเงินเมื่อ'] = pd.to_datetime(line['ชำระเงินเมื่อ'],errors='ignore')

# %%
line.dtypes
# Out:
# #                                    int64
# เลขรายการสั่งซื้อ                    int64
# ช่องทางการขาย                       object
# สร้างเมื่อ                  datetime64[ns]
# ยืนยันการสั่งซื้อเมื่อ      datetime64[ns]
# ชำระเงินเมื่อ               datetime64[ns]
# ชื่อลูกค้า                          object
# ชื่อผู้รับสินค้า                    object
# เบอร์โทรผู้รับสินค้า                 int64
# อีเมลผู้รับสินค้า                   object
# ที่อยู่จัดส่ง                       object
# จังหวัด                             object
# รหัสไปรษณีย์                         int64
# บริษัทจัดส่ง                        object
# วิธีจัดส่ง                          object
# ค่าจัดส่ง                          float64
# วิธีการชำระเงิน                     object
# ราคาขาย                              int64
# ราคาเต็ม                             int64
# รหัสสินค้า                          object
# รหัส SKU                            object
# บาร์โค้ด                           float64
# ...

# %%
line.head()
# Out:
#    #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 0  1   2021100912646364    Storefront 2021-10-09 12:37:00
# 1  2   2021100912646339    Storefront 2021-10-09 12:37:00
# 2  3   2021100912656389    Storefront 2021-10-09 16:30:00
# 3  4   2021100912656817    Storefront 2021-10-09 16:38:00
# 4  5   2021100912658479    Storefront 2021-10-09 17:19:00
#
#   ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ        ชื่อลูกค้า  \
# 0    2021-10-09 12:43:00 2021-10-09 13:48:00      SC001 หมิว ว
# 1    2021-10-09 15:57:00 2021-10-10 17:19:00            ตรีคูณ
# 2    2021-10-09 16:33:00 2021-10-10 17:20:00              M00k
# 3    2021-10-09 16:44:00 2021-10-10 17:20:00  Watchara Tavapak
# 4    2021-10-09 18:40:00 2021-10-10 17:20:00      นุรดีนา แวแม
#
#       ชื่อผู้รับสินค้า  เบอร์โทรผู้รับสินค้า            อีเมลผู้รับสินค้า  \
# 0   ศิริวรรณ วิชิตแย้ม              98078031  siriwan.wichityam@gmail.com
# 1   ตรีคูณ สุวรรณพฤกษ์             634618231       treekoon2546@gmail.com
# ...

# %%
set(line['ชื่อสินค้า'])
# Out:
# {'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ + คอร์สเฉลยละเอียด กว่า 20 ชั่วโมง',
#  'E-Book สรุปเนื้อหา ม.ปลาย + คอร์สสรุปเนื้อหา ม.ปลาย เตรียมสอบ TCAS',
#  'E-Book สรุปเนื้อหา ม.ปลาย ฟรี คอร์สสรุปเนื้อหา ม.ปลาย เตรียมสอบ TCAS กว่า 25 ชม.',
#  'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65',
#  'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65 ฟรี! คอร์สติว 21 ชม.',
#  'E-Book เตรียมสอบครุศาสตร์/ศึกษาศาสตร์',
#  'E-Book เตรียมสอบครุศาสตร์/ศึกษาศาสตร์ ฟรี คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง ..',
#  'E-Book เตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่า เกณฑ์ใหม่ ตามแนว สสวท.',
#  'E-Book เตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่า เกณฑ์ใหม่ ตามแนว สสวท. คอร์สติว กว่า 10 ชั่วโมง',
#  'E-Book เตรียมสอบมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน',
#  'E-Book เตรียมสอบสายแพทย์ วิทยาศาสตร์สุขภาพ',
#  'E-book เตรียมสอบวิศวกรรมศาสตร์',
#  'E-book เตรียมสอบวิศวกรรมศาสตร์ ฟรี คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง',
# ...

# %%
line['ชื่อสินค้า'].replace({'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ + คอร์สเฉลยละเอียด กว่า 20 ชั่วโมง':'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
'E-Book สรุปเนื้อหา ม.ปลาย + คอร์สสรุปเนื้อหา ม.ปลาย เตรียมสอบ TCAS':'E-Book สรุปม.ปลาย Tcas',
'E-Book สรุปเนื้อหา ม.ปลาย ฟรี คอร์สสรุปเนื้อหา ม.ปลาย เตรียมสอบ TCAS กว่า 25 ชม.':'E-Book สรุปม.ปลาย Tcas',
'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65':'E-Book เตรียมสอบ Netsat',
'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65 ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
'E-Book เตรียมสอบครุศาสตร์/ศึกษาศาสตร์':'E-Book เตรียมสอบครู',
'E-Book เตรียมสอบครุศาสตร์/ศึกษาศาสตร์ ฟรี คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง ..':'E-Book เตรียมสอบครู',
'E-Book เตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่า เกณฑ์ใหม่ ตามแนว สสวท.':'E-Book เตรียมสอบพยาบาล',
'E-Book เตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่า เกณฑ์ใหม่ ตามแนว สสวท. คอร์สติว กว่า 10 ชั่วโมง':'E-Book เตรียมสอบพยาบาล',
'E-Book เตรียมสอบมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'E-Book เตรียมสอบมนุษย์ นิติ บริหาร',
'E-Book เตรียมสอบสายแพทย์ วิทยาศาสตร์สุขภาพ':'E-Book สายแพทย์-วิทย์สุขภาพ',
'E-book เตรียมสอบวิศวกรรมศาสตร์':'E-Book เตรียมสอบวิศวะ',
'E-book เตรียมสอบวิศวกรรมศาสตร์ ฟรี คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'E-Book เตรียมสอบวิศวะ',
'หนังสือ  TCAS เฉลยละเอียดวิชาสามัญชีววิทยา':'หนังสือสามัญ ชีววิทยา',
'หนังสือ TCAS  เฉลยละเอียดวิชาสามัญเคมี':'หนังสือสามัญ เคมี',
'หนังสือ TCAS สรุปเนื้อหา ม.ปลาย + ฟรี คอร์สสรุปเนื้อหา ม.ปลาย 25 ชม.':'หนังสือสรุปม.ปลาย Tcas',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญคณิตศาสตร์':'หนังสือสามัญ คณิตศาสตร์',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญฟิสิกส์':'หนังสือสามัญ ฟิสิกส์',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญภาษาอังกฤษ':'หนังสือสามัญ ภาษาอังกฤษ',
'หนังสือ TCAS เฉลยละเอียดวิชาสามัญภาษาไทย + สังคม':'หนังสือสามัญ ภาษาไทย + สังคม',
'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ + คอร์สเฉลยละเอียด กว่า 20 ชั่วโมง':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ + ฟรี คอร์สเฉลยละเอียด กว่า 20 ชั่วโมง':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
'หนังสือสรุปเนื้อหา ม.ปลาย + คอร์สสรุปเนื้อหา ม.ปลาย เตรียมสอบ TCAS เล่มเดียวจบครบทุกวิชา':'หนังสือสรุปม.ปลาย Tcas',
'หนังสือสรุปเนื้อหา ม.ปลาย พร้อมคอร์สติวสรุป 25 ชม. พิชิต TCAS66 67 เกณฑ์ใหม่':'หนังสือสรุปม.ปลาย Tcas',
'หนังสือเฉลยละเอียดวิชาสามัญคณิตศาสตร์':'หนังสือสามัญ คณิตศาสตร์',
'หนังสือเฉลยละเอียดวิชาสามัญชีววิทยา':'หนังสือสามัญ ชีววิทยา',
'หนังสือเฉลยละเอียดวิชาสามัญฟิสิกส์':'หนังสือสามัญ ฟิสิกส์',
'หนังสือเฉลยละเอียดวิชาสามัญภาษาอังกฤษ':'หนังสือสามัญ ภาษาอังกฤษ',
'หนังสือเฉลยละเอียดวิชาสามัญภาษาไทย + สังคม':'หนังสือสามัญ ภาษาไทย + สังคม',
'หนังสือเฉลยละเอียดวิชาสามัญเคมี':'หนังสือสามัญ เคมี',
'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65 ฟรี! คอร์สติว 21 ชม.':'หนังสือเตรียมสอบ Netsat',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 เกณฑ์ใหม่':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 เกณฑ์ใหม่ ฟรี คอร์สติวความถนัดแพทย์ 6 ชม.':'หนังสือแพทย์-ทันตะ',
'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์':'หนังสือเตรียมสอบครู',
'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ ฟรี คอร์สติว 10 ชม.':'หนังสือเตรียมสอบครู',
'หนังสือเตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่า เกณฑ์ใหม่ ตามแนว สสวท. รวมข้อสอบจริงและเฉลย':'หนังสือเตรียมสอบพยาบาล',
'หนังสือเตรียมสอบพยาบาลพระบรม/พยาบาล 4 เหล่าตามแนว สสวท. ฟรีคอร์สเฉลย 10 ชม.':'หนังสือเตรียมสอบพยาบาล',
'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบวิศวกรรมศาสตร์ ฟรีคอร์สเฉลย 10 ชม.':'หนังสือเตรียมสอบวิศวะ',
'หนังสือเตรียมสอบสายแพทย์ วิทยาศาสตร์สุขภาพ':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือเตรียมสอบสายแพทย์ วิทยาศาสตร์สุขภาพ ฟรี คอร์สติว 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
'หนังสือแนวข้อสอบสมรรถนะ มข. 65':'หนังสือเตรียมสอบ Netsat',
'หนังสือแนวข้อสอบสมรรถนะ มข. 65 ฟรีคอร์สเฉลย 15 ชม.':'หนังสือเตรียมสอบ Netsat',
},inplace=True)

# %%
set(line['ชื่อสินค้า'])
# Out:
# {'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'E-Book สรุปม.ปลาย Tcas',
#  'E-Book สายแพทย์-วิทย์สุขภาพ',
#  'E-Book เตรียมสอบ Netsat',
#  'E-Book เตรียมสอบครู',
#  'E-Book เตรียมสอบพยาบาล',
#  'E-Book เตรียมสอบมนุษย์ นิติ บริหาร',
#  'E-Book เตรียมสอบวิศวะ',
#  'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'หนังสือสรุปม.ปลาย Tcas',
#  'หนังสือสามัญ คณิตศาสตร์',
#  'หนังสือสามัญ ชีววิทยา',
#  'หนังสือสามัญ ฟิสิกส์',
#  'หนังสือสามัญ ภาษาอังกฤษ',
#  'หนังสือสามัญ ภาษาไทย + สังคม',
#  'หนังสือสามัญ เคมี',
#  'หนังสือสายแพทย์-วิทย์สุขภาพ',
#  'หนังสือเตรียมสอบ Netsat',
#  'หนังสือเตรียมสอบครู',
#  'หนังสือเตรียมสอบพยาบาล',
#  'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
#  'หนังสือเตรียมสอบวิศวะ',
#  'หนังสือแพทย์-ทันตะ',
#  'เสื้อยืด คอกลม  เรืองแสง',
#  'เสื้อยืด สีเขียว'}

# %%
line_new = line.drop(line[line['ชื่อสินค้า']=='เสื้อยืด คอกลม  เรืองแสง'].index, inplace=True)

# %%
line.drop(line[line['ชื่อสินค้า']=='เสื้อยืด สีเขียว'].index, inplace=True)

# %%
set(line['ชื่อสินค้า'])
# Out:
# {'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'E-Book สรุปม.ปลาย Tcas',
#  'E-Book สายแพทย์-วิทย์สุขภาพ',
#  'E-Book เตรียมสอบ Netsat',
#  'E-Book เตรียมสอบครู',
#  'E-Book เตรียมสอบพยาบาล',
#  'E-Book เตรียมสอบมนุษย์ นิติ บริหาร',
#  'E-Book เตรียมสอบวิศวะ',
#  'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'หนังสือสรุปม.ปลาย Tcas',
#  'หนังสือสามัญ คณิตศาสตร์',
#  'หนังสือสามัญ ชีววิทยา',
#  'หนังสือสามัญ ฟิสิกส์',
#  'หนังสือสามัญ ภาษาอังกฤษ',
#  'หนังสือสามัญ ภาษาไทย + สังคม',
#  'หนังสือสามัญ เคมี',
#  'หนังสือสายแพทย์-วิทย์สุขภาพ',
#  'หนังสือเตรียมสอบ Netsat',
#  'หนังสือเตรียมสอบครู',
#  'หนังสือเตรียมสอบพยาบาล',
#  'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
#  'หนังสือเตรียมสอบวิศวะ',
#  'หนังสือแพทย์-ทันตะ'}

# %%
line
# Out:
#          #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 0        1   2021100912646364    Storefront 2021-10-09 12:37:00
# 1        2   2021100912646339    Storefront 2021-10-09 12:37:00
# 2        3   2021100912656389    Storefront 2021-10-09 16:30:00
# 3        4   2021100912656817    Storefront 2021-10-09 16:38:00
# 4        5   2021100912658479    Storefront 2021-10-09 17:19:00
# ...    ...                ...           ...                 ...
# 1802  1803   2022050224703621    Storefront 2022-05-02 10:31:00
# 1803  1804   2022050224709580    Storefront 2022-05-02 11:58:00
# 1804  1805   2022010116875576    Storefront 2022-01-01 19:18:00
# 1805  1806   2022050224751429    Storefront 2022-05-03 04:44:00
# 1806  1807   2022050324758617    Storefront 2022-05-03 09:53:00
#
#      ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ          ชื่อลูกค้า  \
# 0       2021-10-09 12:43:00 2021-10-09 13:48:00        SC001 หมิว ว
# ...

# %%
set(line['จังหวัด'])
# Out:
# {' จ.เพชรบรูณ์',
#  ' จังหวัดอำนาจเจริญ',
#  ' สงขลา',
#  ' สระบุรี',
#  '-',
#  'Kalasin',
#  'Khonkaen',
#  'กทม',
#  'กทม.',
#  'กระบี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร ',
#  'กรุงเทพฯ',
#  'กาญจนบุรี',
#  'กาฬสิน',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\u200b',
#  'กำแพงเพชร',
#  'ขอนเเก่น',
#  'ขอนแก่น',
#  'ขอนแก่น ',
#  'ขอนแก่น\u200b',
#  'จ.กาฬสินธุ์',
#  'จ.ขอนเเก่น ',
#  'จ.ขอนแก่น',
#  'จ.ชัยนาท',
#  'จ.ตราด',
#  'จ.นครพนม',
#  'จ.นครราชสีมา',
#  'จ.นครศรีธรรมราช',
#  'จ.นครสวรรค์',
#  'จ.บึงกาฬ',
#  'จ.บุรีรัมย์',
#  'จ.ปทุมธานี',
#  'จ.ปัตตานี',
#  'จ.พิษณุโลก',
#  'จ.มหาสารคาม',
#  'จ.ร้อยเอ็ด',
#  'จ.ศรีสะเกษ',
#  'จ.สกลนคร',
#  'จ.สมุทรสาคร',
#  'จ.สระบุรี',
#  'จ.อถดรธานี',
#  'จ.อุดรธานี',
#  'จ.อุบลราชธานี',
#  'จ.เชียงใหม่',
#  'จังหวัดฉะเชิงเทรา',
#  'จังหวัดชลบุรี',
#  'จังหวัดมหาสารคาม ',
#  'จังหวัดยโสธร',
#  'จังหวัดร้อยเอ็ด',
#  'จังหวัดศรีสะเกษ',
#  'จังหวัดเพชรบูรณ์',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุ',
#  'ชลบุรี',
#  'ชัยนาท',
# ...

# %%
line[line['จังหวัด']=='-']
# Out:
#        #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 89    90   2021101913118913    Storefront 2021-10-19 21:06:00
# 781  782   2021122016361807    Storefront 2021-12-20 10:37:00
#
#     ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ ชื่อลูกค้า  \
# 89     2021-10-19 21:15:00 2021-10-20 10:21:00      𝖂𝖍𝖆𝖑𝖊
# 781    2021-12-21 10:14:00 2021-12-21 11:00:00      ~ 92💡
#
#          ชื่อผู้รับสินค้า  เบอร์โทรผู้รับสินค้า          อีเมลผู้รับสินค้า  \
# 89   นายชัชวาลย์ ฮวดมาลัย             868501635  chatchawans2004@gmail.com
# 781          กชวรรณ พูลผล             954654329                        NaN
#
#      ... สถานะการจัดส่ง สถานะการสั่งซื้อ  ถูกยกเลิกเมื่อ เหตุผลการยกเลิก  \
# 89   ...  Ready to ship      In progress             NaN             NaN
# 781  ...        Shipped        Completed             NaN             NaN
#
#     ข้อความจากผู้ขาย  ข้อความจากผู้ซื้อ รหัสส่วนลด  ส่วนลด  \
# 89               NaN                NaN        NaN     0.0
# ...

# %%
line['จังหวัด'].replace({' จ.เพชรบรูณ์':'จังหวัดเพชรบูรณ์',
 ' จังหวัดอำนาจเจริญ':'จังหวัดอำนาจเจริญ',
 ' สงขลา':'จังหวัดสงขลา',
 ' สระบุรี':'จังหวัดสระบุรี',
 'Kalasin':'จังหวัดกาฬสินธุ์',
 'Khonkaen':'จังหวัดขอนแก่น',
 'กทม':'จังหวัดกรุงเทพมหานคร',
 'กทม.':'จังหวัดกรุงเทพมหานคร',
 'กระบี่':'จังหวัดกระบี่',
 'กรุงเทพ':'จังหวัดกรุงเทพมหานคร',
 'กรุงเทพมหานคร':'จังหวัดกรุงเทพมหานคร',
 'กรุงเทพมหานคร ':'จังหวัดกรุงเทพมหานคร',
 'กรุงเทพฯ':'จังหวัดกรุงเทพมหานคร',
 'กาญจนบุรี':'จังหวัดกาญจนบุรี',
 'กาฬสิน':'จังหวัดกาฬสินธุ์',
 'กาฬสินธุ์':'จังหวัดกาฬสินธุ์',
 'กาฬสินธุ์\u200b':'จังหวัดกาฬสินธุ์',
 'กำแพงเพชร':'จังหวัดกำแพงเพชร',
 'ขอนเเก่น':'จังหวัดขอนแก่น',
 'ขอนแก่น':'จังหวัดขอนแก่น',
 'ขอนแก่น ':'จังหวัดขอนแก่น',
 'ขอนแก่น\u200b':'จังหวัดขอนแก่น',
 'จ.กาฬสินธุ์':'จังหวัดกาฬสินธุ์',
 'จ.ขอนเเก่น ':'จังหวัดขอนแก่น',
 'จ.ขอนแก่น':'จังหวัดขอนแก่น',
 'จ.ชัยนาท':'จังหวัดชัยนาท',
 'จ.ตราด':'จังหวัดตราด',
 'จ.นครพนม':'จังหวัดนครพนม',
 'จ.นครราชสีมา':'จังหวัดนครราชสีมา',
 'จ.นครศรีธรรมราช':'จังหวัดนครศรีธรรมราช',
 'จ.นครสวรรค์':'จังหวัดนครสวรรค์',
 'จ.บึงกาฬ':'จังหวัดบึงกาฬ',
 'จ.บุรีรัมย์':'จังหวัดบุรีรัมย์',
 'จ.ปทุมธานี':'จังหวัดปทุมธานี',
 'จ.ปัตตานี':'จังหวัดปัตตานี',
 'จ.พิษณุโลก':'จังหวัดพิษณุโลก',
 'จ.มหาสารคาม':'จังหวัดมหาสารคาม',
 'จ.ร้อยเอ็ด':'จังหวัดร้อยเอ็ด',
 'จ.ศรีสะเกษ':'จังหวัดศรีสะเกษ',
 'จ.สกลนคร':'จังหวัดสกลนคร',
 'จ.สมุทรสาคร':'จังหวัดสมุทรสาคร',
 'จ.สระบุรี':'จังหวัดสระบุรี',
 'จ.อถดรธานี':'จังหวัดอุดรธานี',
 'จ.อุดรธานี':'จังหวัดอุดรธานี',
 'จ.อุบลราชธานี':'จังหวัดอุบลราชธานี',
 'จ.เชียงใหม่':'จังหวัดเชียงใหม่',
 'จังหวัดมหาสารคาม ':'จังหวัดมหาสารคาม',
 'จันทบุรี':'จังหวัดจันทบุรี',
 'ฉะเชิงเทรา':'จังหวัดฉะเชิงเทรา',
 'ชลบุ':'จังหวัดชลบุรี',
 'ชลบุรี':'จังหวัดชลบุรี',
 'ชัยนาท':'จังหวัดชัยนาท',
 'ชัยภูมิ':'จังหวัดชัยภูมิ',
 'ชัยภูมิ\u200b':'จังหวัดชัยภูมิ',
 'ชุมพร':'จังหวัดชุมพร',
 'ตรัง':'จังหวัดตรัง',
 'ตราด':'จังหวัดตราด',
 'ตราษ':'จังหวัดตราด',
 'ตาก':'จังหวัดตาก',
 'ตำบล ช้างเผือก  อำเภอ เมือง จังหวัด เชียงใหม่':'จังหวัดเชียงใหม่',
 'นครนายก':'จังหวัดนครนายก',
 'นครปฐม':'จังหวัดนครปฐม',
 'นครพนม':'จังหวัดนครพนม',
 'นครพนม\u200b':'จังหวัดนครพนม',
 'นครพนสม':'จังหวัดนครพนม',
 'นครราชสีมา':'จังหวัดนครราชสีมา',
 'นครราชสีมา ':'จังหวัดนครราชสีมา',
 'นครราชสีมา\u200b':'จังหวัดนครราชสีมา',
 'นครศรีธรรมราช':'จังหวัดนครศรีธรรมราช',
 'นครศรีธรรมราช\u200b':'จังหวัดนครศรีธรรมราช',
 'นครสวรรค์':'จังหวัดนครสวรรค์',
 'นคสวรรค์':'จังหวัดนครสวรรค์',
 'นนทบุรี':'จังหวัดนนทบุรี',
 'นนทบุรี\u200b':'จังหวัดนนทบุรี',
 'นราธิวาส':'จังหวัดนราธิวาส',
 'น่าน':'จังหวัดน่าน',
 'บึงกาฬ':'จังหวัดบึงกาฬ',
 'บึงกาฬ\u200b':'จังหวัดบึงกาฬ',
 'บุรีรัมย์':'จังหวัดบุรีรัมย์',
 'บุรีรัมย์ ':'จังหวัดบุรีรัมย์',
 'บุรีรัมย์\u200b':'จังหวัดบุรีรัมย์',
 'ปทุมธานี':'จังหวัดปทุมธานี',
 'ประจวบคีรีขันธ์':'จังหวัดประจวบคีรีขันธ์',
 'ปราจีนบุรี':'จังหวัดปราจีนบุรี',
 'ปัตตานี':'จังหวัดปัตตานี',
 'พระนครศครีอยุธยา':'จังหวัดพระนครศรีอยุธยา',
 'พระนครศรีอยุธยา':'จังหวัดพระนครศรีอยุธยา',
 'พะเยา':'จังหวัดพะเยา',
 'พังงา':'จังหวัดพังงา',
 'พัทลุง':'จังหวัดพัทลุง',
 'พิจิตร':'จังหวัดพิจิตร',
 'พิษณุโลก':'จังหวัดพิษณุโลก',
 'ภูเก็ต':'จังหวัดภูเก็ต',
 'มหารสารคาม':'จังหวัดมหาสารคาม',
 'มหาสารคาม':'จังหวัดมหาสารคาม',
 'มุกดาหาร':'จังหวัดมุกดาหาร',
 'ยะลา':'จังหวัดยะลา',
 'ยโสธร':'จังหวัดยโสธร',
 'ระนอง':'จังหวัดระนอง',
 'ระยอง':'จังหวัดระยอง',
 'ราชบุรี':'จังหวัดราชบุรี',
 'ร่อยเอ็ด':'จังหวัดร้อยเอ็ด',
 'ร้อยเอ':'จังหวัดร้อยเอ็ด',
 'ร้อยเอ็ด':'จังหวัดร้อยเอ็ด',
 'ร้อยเอ็ด\u200b':'จังหวัดร้อยเอ็ด',
 'ลพบุรี':'จังหวัดลพบุรี',
 'ลำปาง':'จังหวัดลำปาง',
 'ลำพูน':'จังหวัดลำพูน',
 'ศรีสะเกศ':'จังหวัดศรีสะเกษ',
 'ศรีสะเกษ':'จังหวัดศรีสะเกษ',
 'สกลนคร':'จังหวัดสกลนคร',
 'สงขลา':'จังหวัดสงขลา',
 'สตูล':'จังหวัดสตูล',
 'สมุทรปราการ':'จังหวัดสมุทรปราการ',
 'สมุทรปราการ ':'จังหวัดสมุทรปราการ',
 'สมุทรปราการ\u200b':'จังหวัดสมุทรปราการ',
 'สมุทรสงคราม':'จังหวัดสมุทรสงคราม',
 'สมุทรสาคร':'จังหวัดสมุทรสาคร',
 'สระบุรี':'จังหวัดสระบุรี',
 'สระแก้ว':'จังหวัดสระแก้ว',
 'สิงห์บุรี':'จังหวัดสิงห์บุรี',
 'สุพรร':'จังหวัดสุพรรณบุรี',
 'สุพรรณบุรี':'จังหวัดสุพรรณบุรี',
 'สุราษฎร์ธานี':'จังหวัดสุราษฎร์ธานี',
 'สุราษฏร์ธานี':'จังหวัดสุราษฎร์ธานี',
 'สุรินทร์':'จังหวัดสุรินทร์',
 'สุโขทัย':'จังหวัดสุโขทัย',
 'หนองคาย':'จังหวัดหนองคาย',
 'หนองบัวลำภู':'จังหวัดหนองบัวลำภู',
 'อำนาจเจริญ':'จังหวัดอำนาจเจริญ',
 'อำนาจเจริญ ':'จังหวัดอำนาจเจริญ',
 'อำนาจเจริฐ':'จังหวัดอำนาจเจริญ',
 'อุดรธานี':'จังหวัดอุดรธานี',
 'อุดรธานี\u200b':'จังหวัดอุดรธานี',
 'อุดร\u200bธานี':'จังหวัดอุดรธานี',
 'อุตรดิตถ์':'จังหวัดอุตรดิตถ์',
 'อุทัยธานี':'จังหวัดอุทัยธานี',
 'อุทุมพรพิสัย':'จังหวัดศรีสะเกษ',
 'อุบลรา':'จังหวัดอุบลราชธานี',
 'อุบลราช':'จังหวัดอุบลราชธานี',
 'อุบลราชธานี':'จังหวัดอุบลราชธานี',
 'อุบลราชธานี\u200b':'จังหวัดอุบลราชธานี',
 'อ่างทอง':'จังหวัดอ่างทอง',
 'เชียงราย':'จังหวัดเชียงราย',
 'เชียงใหม่':'จังหวัดเชียงใหม่',
 'เพชรบุรี':'จังหวัดเพชรบุรี',
 'เพชรบูรณ์':'จังหวัดเพชรบูรณ์',
 'เลย':'จังหวัดเลย',
 'เเพร่':'จังหวัดแพร่',
 'แพร่':'จังหวัดแพร่',
 'แพร่ ':'จังหวัดแพร่',
 'แม่ฮ่อง':'จังหวัดแม่ฮ่องสอน',
 'แม่ฮ่องสอน':'จังหวัดแม่ฮ่องสอน'
},inplace=True)

# %%
line.head()
# Out:
#    #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 0  1   2021100912646364    Storefront 2021-10-09 12:37:00
# 1  2   2021100912646339    Storefront 2021-10-09 12:37:00
# 2  3   2021100912656389    Storefront 2021-10-09 16:30:00
# 3  4   2021100912656817    Storefront 2021-10-09 16:38:00
# 4  5   2021100912658479    Storefront 2021-10-09 17:19:00
#
#   ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ        ชื่อลูกค้า  \
# 0    2021-10-09 12:43:00 2021-10-09 13:48:00      SC001 หมิว ว
# 1    2021-10-09 15:57:00 2021-10-10 17:19:00            ตรีคูณ
# 2    2021-10-09 16:33:00 2021-10-10 17:20:00              M00k
# 3    2021-10-09 16:44:00 2021-10-10 17:20:00  Watchara Tavapak
# 4    2021-10-09 18:40:00 2021-10-10 17:20:00      นุรดีนา แวแม
#
#       ชื่อผู้รับสินค้า  เบอร์โทรผู้รับสินค้า            อีเมลผู้รับสินค้า  \
# 0   ศิริวรรณ วิชิตแย้ม              98078031  siriwan.wichityam@gmail.com
# 1   ตรีคูณ สุวรรณพฤกษ์             634618231       treekoon2546@gmail.com
# ...

# %%
set(line['จังหวัด'])
# Out:
# {'-',
#  'จังหวัดกระบี่',
#  'จังหวัดกรุงเทพมหานคร',
#  'จังหวัดกาญจนบุรี',
#  'จังหวัดกาฬสินธุ์',
#  'จังหวัดกำแพงเพชร',
#  'จังหวัดขอนแก่น',
#  'จังหวัดจันทบุรี',
#  'จังหวัดฉะเชิงเทรา',
#  'จังหวัดชลบุรี',
#  'จังหวัดชัยนาท',
#  'จังหวัดชัยภูมิ',
#  'จังหวัดชุมพร',
#  'จังหวัดตรัง',
#  'จังหวัดตราด',
#  'จังหวัดตาก',
#  'จังหวัดนครนายก',
#  'จังหวัดนครปฐม',
#  'จังหวัดนครพนม',
#  'จังหวัดนครราชสีมา',
#  'จังหวัดนครศรีธรรมราช',
#  'จังหวัดนครสวรรค์',
#  'จังหวัดนนทบุรี',
#  'จังหวัดนราธิวาส',
#  'จังหวัดน่าน',
#  'จังหวัดบึงกาฬ',
#  'จังหวัดบุรีรัมย์',
#  'จังหวัดปทุมธานี',
#  'จังหวัดประจวบคีรีขันธ์',
#  'จังหวัดปราจีนบุรี',
#  'จังหวัดปัตตานี',
#  'จังหวัดพระนครศรีอยุธยา',
#  'จังหวัดพะเยา',
#  'จังหวัดพังงา',
#  'จังหวัดพัทลุง',
#  'จังหวัดพิจิตร',
#  'จังหวัดพิษณุโลก',
#  'จังหวัดภูเก็ต',
#  'จังหวัดมหาสารคาม',
#  'จังหวัดมุกดาหาร',
#  'จังหวัดยะลา',
#  'จังหวัดยโสธร',
#  'จังหวัดระนอง',
#  'จังหวัดระยอง',
#  'จังหวัดราชบุรี',
#  'จังหวัดร้อยเอ็ด',
#  'จังหวัดลพบุรี',
# ...

# %%
line.to_csv('Line_All3.csv', encoding='utf-8')

# %% [markdown]
# # **Lazada**

# %%
data_file_path = os.path.join(path,'LAZADA_ALL.xlsx')  
lazada = pd.read_excel(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
lazada.head()
# Out:
#        orderItemId orderType      Guarantee deliveryType         lazadaId  \
# 0  534256428958418    NORMAL  non-Guarantee     STANDARD  534256428958418
# 1  534239666792421    NORMAL  non-Guarantee     STANDARD  534239666792421
# 2  534239666892421    NORMAL  non-Guarantee     STANDARD  534239666892421
# 3  534239666992421    NORMAL  non-Guarantee     STANDARD  534239666992421
# 4  534239667092421    NORMAL  non-Guarantee     STANDARD  534239667092421
#
#                     sellerSku                  lazadaSku  wareHouse  \
# 0  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 1                       JK005  2935952310_TH-10765229524        NaN
# 2  2935815524-1636010011275-0  2935815524_TH-10765234096        NaN
# 3  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 4  2935063465-1635999445201-0  2935063465_TH-10761829862        NaN
#
#           createTime         updateTime  ...  promisedShippingTime  premium  \
# ...

# %%
lazada['createTime'] = pd.to_datetime(lazada['createTime'],errors='ignore')

# %%
lazada['updateTime'] = pd.to_datetime(lazada['updateTime'],errors='ignore')

# %%
lazada.head()
# Out:
#        orderItemId orderType      Guarantee deliveryType         lazadaId  \
# 0  534256428958418    NORMAL  non-Guarantee     STANDARD  534256428958418
# 1  534239666792421    NORMAL  non-Guarantee     STANDARD  534239666792421
# 2  534239666892421    NORMAL  non-Guarantee     STANDARD  534239666892421
# 3  534239666992421    NORMAL  non-Guarantee     STANDARD  534239666992421
# 4  534239667092421    NORMAL  non-Guarantee     STANDARD  534239667092421
#
#                     sellerSku                  lazadaSku  wareHouse  \
# 0  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 1                       JK005  2935952310_TH-10765229524        NaN
# 2  2935815524-1636010011275-0  2935815524_TH-10765234096        NaN
# 3  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 4  2935063465-1635999445201-0  2935063465_TH-10761829862        NaN
#
#            createTime          updateTime  ...  promisedShippingTime  premium  \
# ...

# %%
set(lazada['itemName'])
# Out:
# {'Jknowledge - หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง',
#  'รวมข้อสอบวิชาสามัญคณิตศาสตร์ พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด',
#  'รวมข้อสอบวิชาสามัญชีววิทยา พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด',
#  'รวมข้อสอบวิชาสามัญเคมี พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด',
#  'หนังสือ TCAS รวมข้อสอบพร้อมเฉลยละเอียดวิชาสามัญภาษาไทย + สังคม 3ปีล่าสุด',
#  'หนังสือ ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล ปฏิบัติการ',
#  'หนังสือติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 + วิดีโอติว 40 ชม.',
#  'หนังสือติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 + วิดีโอติว 5 ชม.',
#  'หนังสือติวและเฉลยข้อสอบจริง ท้องถิ่น (ภาค ก) 64 + วิดีโอติว 35 ชม.',
#  'หนังสือท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน ปฏิบัติการ',
#  'หนังสือรวมข้อสอบพร้อมเฉลยละเอียด วิชาสามัญฟิสิกส์ 5 ปี พ.ศ. ล่าสุด',
#  'หนังสือรวมข้อสอบพร้อมเฉลยละเอียด วิชาสามัญภาษาอังกฤษ 5 ปี พ.ศ. ล่าสุด',
#  'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง)',
# ...

# %%
lazada['itemName'].replace({'Jknowledge - หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบวิศวะ',
 'รวมข้อสอบวิชาสามัญคณิตศาสตร์ พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด':'หนังสือสามัญ คณิตศาสตร์',
 'รวมข้อสอบวิชาสามัญชีววิทยา พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด':'หนังสือสามัญ ชีววิทยา',
 'รวมข้อสอบวิชาสามัญเคมี พร้อมเฉลยละเอียด 5 ปี พ.ศ. ล่าสุด':'หนังสือสามัญ เคมี',
 'หนังสือ TCAS รวมข้อสอบพร้อมเฉลยละเอียดวิชาสามัญภาษาไทย + สังคม 3ปีล่าสุด':'หนังสือสามัญ ภาษาไทย + สังคม',
 'หนังสือ ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
 'หนังสือติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 + วิดีโอติว 40 ชม.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 + วิดีโอติว 5 ชม.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวและเฉลยข้อสอบจริง ท้องถิ่น (ภาค ก) 64 + วิดีโอติว 35 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
 'หนังสือท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน ปฏิบัติการ':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)',
 'หนังสือรวมข้อสอบพร้อมเฉลยละเอียด วิชาสามัญฟิสิกส์ 5 ปี พ.ศ. ล่าสุด':'หนังสือสามัญ ฟิสิกส์',
 'หนังสือรวมข้อสอบพร้อมเฉลยละเอียด วิชาสามัญภาษาอังกฤษ 5 ปี พ.ศ. ล่าสุด':'หนังสือสามัญ ภาษาอังกฤษ',
 'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง)':'หนังสือสมรรถนะ มข',
 'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท.':'หนังสือสรุปม.ปลาย Tcas',
 'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 20 ชม.':'หนังสือสรุปม.ปลาย Tcas',
 'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี🔥คอร์สติววิชาสามัญ 64 และเฉลยละเอียดทุกข้อ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
 'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวจบครบทุกด้าน พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
 'หนังสือเตรียมสอบ สายแพทย์ วิทยาศาสตร์สุขภาพ':'หนังสือสายแพทย์-วิทย์สุขภาพ',
 'หนังสือเตรียมสอบ สายแพทย์ วิทยาศาสตร์สุขภาพ ฟรี! คอร์สติวเตรียมสายแพทย์ 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
 'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66':'หนังสือแพทย์-ทันตะ',
 'หนังสือเตรียมสอบครู ครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบครู',
 'หนังสือเตรียมสอบพยาบาลและเฉลย + วิดีโอติว กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
 'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย + คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3 กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบวิศวะ'
},inplace=True)

# %%
set(lazada['itemName'])
# Out:
# {'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'หนังสือสมรรถนะ มข',
#  'หนังสือสรุปม.ปลาย Tcas',
#  'หนังสือสามัญ คณิตศาสตร์',
#  'หนังสือสามัญ ชีววิทยา',
#  'หนังสือสามัญ ฟิสิกส์',
#  'หนังสือสามัญ ภาษาอังกฤษ',
#  'หนังสือสามัญ ภาษาไทย + สังคม',
#  'หนังสือสามัญ เคมี',
#  'หนังสือสายแพทย์-วิทย์สุขภาพ',
#  'หนังสือเตรียมสอบ Netsat',
#  'หนังสือเตรียมสอบ ก.พ.',
#  'หนังสือเตรียมสอบครู',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)',
#  'หนังสือเตรียมสอบพยาบาล',
#  'หนังสือเตรียมสอบวิศวะ',
#  'หนังสือแพทย์-ทันตะ'}

# %%
set(lazada['billingAddr3'])
# Out:
# {'กระบี่/ Krabi',
#  'กรุงเทพมหานคร/ Bangkok',
#  'กาญจนบุรี/ Kanchanaburi',
#  'กาฬสินธุ์/ Kalasin',
#  'กำแพงเพชร/ Kamphaeng Phet',
#  'ขอนแก่น/ Khon Kaen',
#  'จันทบุรี/ Chanthaburi',
#  'ฉะเชิงเทรา/ Chachoengsao',
#  'ชลบุรี/ Chonburi',
#  'ชัยนาท/ Chainat',
#  'ชัยภูมิ/ Chaiyaphum',
#  'ชุมพร/ Chumphon',
#  'ตรัง/ Trang',
#  'ตราด/ Trat',
#  'ตาก/ Tak',
#  'นครนายก/ Nakhon Nayok',
#  'นครปฐม/ Nakhon Pathom',
#  'นครพนม/ Nakhon Phanom',
#  'นครราชสีมา/ Nakhon Ratchasima',
#  'นครศรีธรรมราช/ Nakhon Si Thammarat',
#  'นครสวรรค์/ Nakhon Sawan',
#  'นนทบุรี/ Nonthaburi',
#  'นราธิวาส/ Narathiwat',
#  'น่าน/ Nan',
#  'บึงกาฬ/ Bueng Kan',
#  'บุรีรัมย์/ Buriram',
#  'ปทุมธานี/ Pathum Thani',
#  'ประจวบคีรีขันธ์/ Prachuap Khiri Khan',
#  'ปราจีนบุรี/ Prachin Buri',
#  'ปัตตานี/ Pattani',
#  'พระนครศรีอยุธยา/ Phra Nakhon Si Ayutthaya',
#  'พะเยา/ Phayao',
#  'พังงา/ Phang Nga',
#  'พัทลุง/ Phatthalung',
#  'พิจิตร/ Phichit',
#  'พิษณุโลก/ Phitsanulok',
#  'ภูเก็ต/ Phuket',
# ...

# %%
print("\n\nSplit 'billingAddr3' column by '/' into two individual columns :\n",
lazada.billingAddr3.str.split(pat='-',expand=True))
# Out:
# Split 'billingAddr3' column by '/' into two individual columns :
#                                0
# 0     สมุทรปราการ/ Samut Prakan
# 1            กาฬสินธุ์/ Kalasin
# 2            กาฬสินธุ์/ Kalasin
# 3            กาฬสินธุ์/ Kalasin
# 4            กาฬสินธุ์/ Kalasin
# ...                         ...
# 1365         บุรีรัมย์/ Buriram
# 1366         กาฬสินธุ์/ Kalasin
# 1367      นครพนม/ Nakhon Phanom
# 1368           ร้อยเอ็ด/ Roi Et
# 1369           ร้อยเอ็ด/ Roi Et
#
# [1370 rows x 1 columns]

# %%
lazada.head()
# Out:
#        orderItemId orderType      Guarantee deliveryType         lazadaId  \
# 0  534256428958418    NORMAL  non-Guarantee     STANDARD  534256428958418
# 1  534239666792421    NORMAL  non-Guarantee     STANDARD  534239666792421
# 2  534239666892421    NORMAL  non-Guarantee     STANDARD  534239666892421
# 3  534239666992421    NORMAL  non-Guarantee     STANDARD  534239666992421
# 4  534239667092421    NORMAL  non-Guarantee     STANDARD  534239667092421
#
#                     sellerSku                  lazadaSku  wareHouse  \
# 0  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 1                       JK005  2935952310_TH-10765229524        NaN
# 2  2935815524-1636010011275-0  2935815524_TH-10765234096        NaN
# 3  2935093878-1636000710131-0  2935093878_TH-10762175987        NaN
# 4  2935063465-1635999445201-0  2935063465_TH-10761829862        NaN
#
#            createTime          updateTime  ...  promisedShippingTime  premium  \
# ...

# %%
lazada.to_csv('lazada_all.csv', encoding='utf-8')

# %% [markdown]
# # **Line Korpor**

# %%
data_file_path = os.path.join(path,'Line_korpor.xlsx')  
kp = pd.read_excel(data_file_path)

# %%
kp.head()
# Out:
#    #  เลขรายการสั่งซื้อ ช่องทางการขาย      สร้างเมื่อ ยืนยันการสั่งซื้อเมื่อ  \
# 0  1   2021100812614625    Storefront  20211008 19:11         20211008 19:20
# 1  2   2021100912640190    Storefront  20211009 10:58         20211009 11:03
# 2  3   2021100912662808    Storefront  20211009 18:56         20211009 19:01
# 3  4   2021100812615930    Storefront  20211008 19:47         20211010 07:33
# 4  5   2021101012723811    Storefront  20211010 19:11         20211010 19:19
#
#     ชำระเงินเมื่อ         ชื่อลูกค้า           ชื่อผู้รับสินค้า  \
# 0  20211009 11:16          nISURAIDa              นิซูไรดา มามะ
# 1  20211009 11:09          🐷NongMoo🐷          สิริรักษ์ คชายุทธ
# 2  20211010 17:08            Mark.SP       สงกรานต์​ ​ผิว​อ่อน​
# 3  20211010 17:08          Thatsanee  นางสาวทรรศนีย์ พริ้งเพราะ
# 4  20211011 10:48  .◡̈⃝ ℬeethoven ◡̈               ภัสสรา ทองดี
#
#    เบอร์โทรผู้รับสินค้า           อีเมลผู้รับสินค้า  ... สถานะการจัดส่ง  \
# ...

# %%
kp['สร้างเมื่อ'] = pd.to_datetime(kp['สร้างเมื่อ'],errors='ignore')
kp['ยืนยันการสั่งซื้อเมื่อ'] = pd.to_datetime(kp['ยืนยันการสั่งซื้อเมื่อ'],errors='ignore')
kp['ชำระเงินเมื่อ'] = pd.to_datetime(kp['ชำระเงินเมื่อ'],errors='ignore')

# %%
kp.head()
# Out:
#    #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 0  1   2021100812614625    Storefront 2021-10-08 19:11:00
# 1  2   2021100912640190    Storefront 2021-10-09 10:58:00
# 2  3   2021100912662808    Storefront 2021-10-09 18:56:00
# 3  4   2021100812615930    Storefront 2021-10-08 19:47:00
# 4  5   2021101012723811    Storefront 2021-10-10 19:11:00
#
#   ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ         ชื่อลูกค้า  \
# 0    2021-10-08 19:20:00 2021-10-09 11:16:00          nISURAIDa
# 1    2021-10-09 11:03:00 2021-10-09 11:09:00          🐷NongMoo🐷
# 2    2021-10-09 19:01:00 2021-10-10 17:08:00            Mark.SP
# 3    2021-10-10 07:33:00 2021-10-10 17:08:00          Thatsanee
# 4    2021-10-10 19:19:00 2021-10-11 10:48:00  .◡̈⃝ ℬeethoven ◡̈
#
#             ชื่อผู้รับสินค้า  เบอร์โทรผู้รับสินค้า  \
# 0              นิซูไรดา มามะ             980510260
# 1          สิริรักษ์ คชายุทธ             933197534
# 2       สงกรานต์​ ​ผิว​อ่อน​             864152914
# ...

# %%
set(kp['ชื่อสินค้า'])
# Out:
# {'E-Book ชุดติวข้อสอบ ก.พ 64-65',
#  'E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม.',
#  'E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 5 ชม.',
#  'E-Book ชุดติวสอบ ท้องถิ่น 64-65 พร้อมวีดีโอเฉลยดูได้ตลอดชีพ',
#  'E-Book ติวสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม. (ไฟล์ PDF)',
#  'คอร์สเร่งรัดสอบผ่าน ก.พ. 64-65 พร้อมหนังสือติวสอบ ก.พ.',
#  'คอร์สเร่งรัดสอบผ่าน ก.พ. 64-65 พร้อมหนังสือติวสอบ ก.พ. และหนังสือเฉลย ก.พ.',
#  'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติว ก.พ. และเฉลยละเอียดข้อสอบจริง กว่า 40 ชั่วโมง',
#  'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติวกว่า 40 ชั่วโมง',
#  'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติวกว่า 5 ชั่วโมง',
#  'หนังสือติวสอบ ก.พ. 64-65 มาพร้อมคอร์สติว ก.พ. และเฉลยละเอียดข้อสอบจริง กว่า 40 ชั่วโมง',
#  'หนังสือเตรียมสอบ ก.พ. 64',
#  'หนังสือเตรียมสอบ ท้องถิ่น 64',
#  'หนังสือเตรียมสอบ ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล',
#  'หนังสือเตรียมสอบ ท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน',
#  'โปร 4.4 E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม.',
# ...

# %%
kp['ชื่อสินค้า'].replace({'E-Book ชุดติวข้อสอบ ก.พ 64-65':'E-Book เตรียมสอบ ก.พ.',
 'E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม.':'E-Book เตรียมสอบ ก.พ.',
 'E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 5 ชม.':'E-Book เตรียมสอบ ก.พ.',
 'E-Book ชุดติวสอบ ท้องถิ่น 64-65 พร้อมวีดีโอเฉลยดูได้ตลอดชีพ':'E-Book เตรียมสอบท้องถิ่น',
 'E-Book ติวสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม. (ไฟล์ PDF)':'E-Book เตรียมสอบ ก.พ.',
 'คอร์สเร่งรัดสอบผ่าน ก.พ. 64-65 พร้อมหนังสือติวสอบ ก.พ.':'หนังสือเตรียมสอบ ก.พ.',
 'คอร์สเร่งรัดสอบผ่าน ก.พ. 64-65 พร้อมหนังสือติวสอบ ก.พ. และหนังสือเฉลย ก.พ.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติว ก.พ. และเฉลยละเอียดข้อสอบจริง กว่า 40 ชั่วโมง':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติวกว่า 40 ชั่วโมง':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวสอบ ก.พ. 64-65 พร้อมคอร์สติวกว่า 5 ชั่วโมง':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวสอบ ก.พ. 64-65 มาพร้อมคอร์สติว ก.พ. และเฉลยละเอียดข้อสอบจริง กว่า 40 ชั่วโมง':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือเตรียมสอบ ก.พ. 64':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือเตรียมสอบ ท้องถิ่น 64':'หนังสือเตรียมสอบท้องถิ่น',
 'หนังสือเตรียมสอบ ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
 'หนังสือเตรียมสอบ ท้องถิ่น ภาค ข ตำแหน่งนักวิเคราะห์นโยบายและแผน':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)',
 'โปร 4.4 E-Book ชุดติวข้อสอบ ก.พ 64-65 พร้อมคอร์สติว 40 ชม.':'E-Book เตรียมสอบ ก.พ.',
 'โปร 4.4 หนังสือติวสอบ ก.พ. 64-65 มาพร้อมคอร์สติว ก.พ. และเฉลยละเอียดข้อสอบจริง กว่า 40 ชั่วโมง':'หนังสือเตรียมสอบ ก.พ.',
 'ไฟล์ E-Book ท้องถิ่น ภาค ข ตำแหน่งนักทรัพยากรบุคคล':'E-Book เตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
 'ไฟล์ E-Book ท้องถิ่น ภาค ข ตำแหน่งนักนโยบายและแผน':'E-Book เตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)'},inplace=True)

# %%
set(kp['ชื่อสินค้า'])
# Out:
# {'E-Book เตรียมสอบ ก.พ.',
#  'E-Book เตรียมสอบท้องถิ่น',
#  'E-Book เตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
#  'E-Book เตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)',
#  'หนังสือเตรียมสอบ ก.พ.',
#  'หนังสือเตรียมสอบท้องถิ่น',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นโยบาย)'}

# %%
set(kp['จังหวัด'])
# Out:
# {' จ.เพชรบูรณ์ ',
#  ' ประจวบ ',
#  '-',
#  'Bangkok',
#  'Nakhon Phanom',
#  'Phuket',
#  'กทม',
#  'กทม.',
#  'กระบี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร ',
#  'กรุงเทพฯ',
#  'กรุงเทพฯ\u200b',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'กำแพงเพชร\u200b',
#  'ขอนแก่น',
#  'จ.นครปฐม',
#  'จ.ปทุมธานี',
#  'จ.ประจวบคีรีขันธ์',
#  'จ.สมุทรปราการ',
#  'จ.อยุธยา',
#  'จ.เชียงใหม่',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุ',
#  'ชลบุรี',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครศรีธรรมราช\u200b',
#  'นครสวรรค์',
#  'นคศรี\u200bธรรมราช\u200b',
#  'นนทบุรี',
#  'นราธิวาส',
#  'นราธิวาส\u200b',
#  'นราธืวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'บุรีรัมย์\u200b',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พระนครศรี\u200bอยุธยา\u200b',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
# ...

# %%
kp['จังหวัด'].replace({' จ.เพชรบูรณ์ ':'เพชรบูรณ์',
 ' ประจวบ ':'ประจวบคีรีขันธ์',
 '-':'ไม่ระบุ',
 'Bangkok':'กรุงเทพมหานคร',
 'Nakhon Phanom':'นครปฐม',
 'Phuket':'ภูเก็ต',
 'กทม':'กรุงเทพมหานคร',
 'กทม.':'กรุงเทพมหานคร',
 'กระบี่':'กระบี่',
 'กรุงเทพ':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร':'กรุงเทพมหานคร',
 'กรุงเทพมหานคร ':'กรุงเทพมหานคร',
 'กรุงเทพฯ':'กรุงเทพมหานคร',
 'กรุงเทพฯ\u200b':'กรุงเทพมหานคร',
 'กาญจนบุรี':'กาญจนบุรี',
 'กาฬสินธุ์':'กาฬสินธุ์',
 'กำแพงเพชร':'กำแพงเพชร',
 'กำแพงเพชร\u200b':'กำแพงเพชร',
 'ขอนแก่น':'ขอนแก่น',
 'จ.นครปฐม':'นครปฐม',
 'จ.ปทุมธานี':'ปทุมธานี',
 'จ.ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'จ.สมุทรปราการ':'สมุทรปราการ',
 'จ.อยุธยา':'พระนครศรีอยุธยา',
 'จ.เชียงใหม่':'เชียงใหม่',
 'จันทบุรี':'จันทบุรี',
 'ฉะเชิงเทรา':'ฉะเชิงเทรา',
 'ชลบุ':'ชลบุรี',
 'ชลบุรี':'ชลบุรี',
 'ชัยภูมิ':'ชัยภูมิ',
 'ชุมพร':'ชุมพร',
 'ตรัง':'ตรัง',
 'ตราด':'ตราด',
 'ตาก':'ตาก',
 'นครนายก':'นครนายก',
 'นครปฐม':'นครปฐม',
 'นครพนม':'บครพนม',
 'นครราชสีมา':'นครราชสีมา',
 'นครศรีธรรมราช':'นครศรีธรรมราช',
 'นครศรีธรรมราช\u200b':'นครศรีธรรมราช',
 'นครสวรรค์':'นครสวรรค์',
 'นคศรี\u200bธรรมราช\u200b':'นครศรีธรรมราช',
 'นนทบุรี':'นนทบุรี',
 'นราธิวาส':'นราธิวาส',
 'นราธิวาส\u200b':'นราธิวาส',
 'นราธืวาส':'นราธิวาส',
 'น่าน':'น่าน',
 'บึงกาฬ':'บึงกาฬ',
 'บุรีรัมย์':'บุรีรัมย์',
 'บุรีรัมย์\u200b':'บุรีรัมย์',
 'ปทุมธานี':'ปทุมธานี',
 'ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์',
 'ปราจีนบุรี':'ปราจีนบุรี',
 'ปัตตานี':'ปัตตานี',
 'พระนครศรีอยุธยา':'พระนครศรีอยุธยา',
 'พระนครศรี\u200bอยุธยา\u200b':'พระนครศรีอยุธยา',
 'พะเยา':'พะเยา',
 'พังงา':'พังงา',
 'พัทลุง':'พัทลุง',
 'พิจิตร':'พิจิตร',
 'พิษณุโลก':'พิษณุโลก',
 'ภูเก็ต':'ภูเก็ต',
 'ภูเก็ต ':'ภูเก็ต',
 'มหาสารคาม':'มหาสารคาม',
 'มุกดาหาร':'มุกดาหาร',
 'ยะลา':'ยะลา',
 'ยโสธร':'ยโสธร',
 'ระนอง':'ระนอง',
 'ระยอง':'ระยอง',
 'ราชบุรี':'ราชบุรี',
 'ร้อยเอ็ด':'ร้อยเอ็ด',
 'ร้อยเอ็ด\u200b':'ร้อยเอ็ด',
 'ลพบุรี':'ลพบุรี',
 'ลำปาง':'ลำปาง',
 'ลำพูน':'ลำพูน',
 'ศรีสะเกษ':'ศรีสะเกษ',
 'สกลนคร':'สกลนคร',
 'สงขลา':'สงขลา',
 'สตูล':'สตูล',
 'สมุทรปราการ':'สมุทรปราการ',
 'สมุทรสาคร':'สมุทรสาคร',
 'สระบุรี':'สระบุรี',
 'สระแก้ว':'สระแก้ว',
 'สายไหม':'ไม่ระบุ',
 'สิงห์บุรี ':'สิงห์บุรี',
 'สุพรรณบุรี':'สุพรรณบุรี',
 'สุราษฎร์ธานี':'สุราษฎร์ธานี',
 'สุรินทร์':'สุรินทร์',
 'สุรินทร์ ':'สุรินทร์',
 'สุโขทัย':'สุโขทัย',
 'หนองคาย':'หนองคาย',
 'หนองบัวลำภู':'หนองบังลำภู',
 'อ.เมือง จ.สงขลา':'สงขลา',
 'อยุธยา':'พระนครศรีอยุธยา',
 'อำนาจเจริญ':'อำนาจเจริญ',
 'อุดร':'อุดรธานี',
 'อุดรธานี':'อุดนธานี',
 'อุดรธานี้':'อุดนธานี',
 'อุตรดิตถ์':'อุตรดิตถ์',
 'อุทัยธานี':'อุทัยธานี',
 'อุบลราชธานี':'อุบลราชธานี',
 'อุบลราชธานี\u200b':'อุบลราชธานี',
 'อ่างทอง':'อ่างทอง',
 'เชียงราย':'เชียงราย',
 'เชียงใหม่':'เชียงใหม่',
 'เพชรบุรี':'เพชรบุรี',
 'เพชรบูรณ์':'เพชรบูรณ์',
 'เลย':'เลย',
 'แพร่':'แพร่'})

# %%
kp[kp['จังหวัด']=='-']
# Out:
#        #  เลขรายการสั่งซื้อ ช่องทางการขาย          สร้างเมื่อ  \
# 664  665   2021111114253228    Storefront 2021-11-11 13:12:00
# 684  685   2022030520784760    Storefront 2022-03-05 20:53:00
#
#     ยืนยันการสั่งซื้อเมื่อ       ชำระเงินเมื่อ ชื่อลูกค้า   ชื่อผู้รับสินค้า  \
# 664    2022-02-15 15:36:00 2022-02-15 16:03:00      ʕ•ᴥ•ʔ  ตรียาพร กานุสนธิ์
# 684    2022-03-05 20:56:00 2022-03-06 11:09:00   WarotKub              วรทย์
#
#      เบอร์โทรผู้รับสินค้า     อีเมลผู้รับสินค้า  ... สถานะการจัดส่ง  \
# 664             903238321  typmind123@gmail.com  ...        Shipped
# 684             891232454   warot.met@gmail.com  ...        Shipped
#
#     สถานะการสั่งซื้อ  ถูกยกเลิกเมื่อ เหตุผลการยกเลิก ข้อความจากผู้ขาย  \
# 664        Completed             NaN             NaN              NaN
# 684        Completed             NaN             NaN              NaN
#
#      ข้อความจากผู้ซื้อ รหัสส่วนลด  ส่วนลด  รหัสส่วนลด LINE SHOPPING  \
# ...

# %%
kp.to_csv('line_korpor.csv', encoding='utf-8')
