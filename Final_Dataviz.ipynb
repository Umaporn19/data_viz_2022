# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/Final_Dataviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # สอบปลายภาค Final

# %% [markdown]
# # รายชื่อสมาชิกในกลุ่ม
#
# **ชื่อกลุ่ม : kibbutzes**
#
# * นางสาวนวลแพร พนาวัฒนวงศ์ รหัสนักศึกษา 623020525-0
# * นางสาวศุภลักษณา บัวจันทร์ รหัสนักศึกษา 623020540-4
# * นางสาวอุมาพร คำภิชัย รหัสนักศึกษา 623020547-0
#
# **ที่มาของแหล่งข้อมูล**
# * https://drive.google.com/drive/folders/1D_Z0fjTki6U6ECbgh2V3wBOSdOXS81YT?fbclid=IwAR0kZ6z2dy5AkdiKZ9_8nNrUUG6Xn4EH0pKfus-lTjiDbf_zn7UwMG0kJyU

# %% [markdown]
# # นำข้อมูลเข้า

# %%
import pandas as pd #import panda เพื่อจัดการตาราง

# %%
from google.colab import drive
drive.mount('/content/drive')  #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
# Out:
# Mounted at /content/drive

# %%
import os 
path = '/content/drive/My Drive/DATA_final' #เชื่อมกับไดร์ฟ

# %% [markdown]
# ## แสดงข้อมูลทั้ง 2 ไฟล์

# %%
data_file_path = os.path.join(path,'alldb.csv')    #ชี้ที่อยู่ในไฟล์
data_alldb = pd.read_csv(data_file_path)
data_alldb #แสดงข้อมูล ของไฟล์ alldb
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %%
data_file_path = os.path.join(path,'hospital_list.xlsx')    #ชี้ที่อยู่ในไฟล์
data_hospital_list = pd.read_excel(data_file_path)
data_hospital_list #แสดงข้อมูล ของไฟล์ hospital_list
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %% [markdown]
# ## จัดการข้อมูล

# %%
new_table =  data_alldb[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']] #เลือกคอลัมม์ที่ต้องการ
new_table #แสดงค่า
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# ...

# %%
new_table.isnull().any() #ตรวจดูค่า missing
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# dtype: bool

# %%
new_table_drop = new_table.dropna() #.dropna เพื่อกำจัดค่า missing ออก
new_table_drop
# Out:
#          user                                RowKey        date  \
# 185     85879                        shmpdrmtgc.png  2022-03-24
# 186    45-161  D2CABB8C-533B-450A-AFA6-B693749CC1C6  2022-02-23
# 187    45-161  57A5F06C-C840-49EA-9514-A30D3C897CC8  2022-02-23
# 188     27529  ADC54E82-4225-4DE6-89A6-A7E556C15FB1  2022-02-25
# 190     06223                        kfpwuaqldj.png  2022-03-23
# ...       ...                                   ...         ...
# 40013   ttest                        crqcufokmn.png  2022-02-21
# 40014   ttest                        gzxgflnowr.png  2022-02-21
# 40016     xxx                        jytlopevha.png  2022-02-17
# 40022     yyy                        ivccsksowb.png  2022-02-17
# 40023     zzz                        psudrnccsh.png  2022-02-17
#
#                    phone   site      time            urine ov PartitionKey
# 185         OPPO CPH2293  05194  13:08:39          มีตะกอน  0         0000
# ...

# %% [markdown]
# ### ทำในส่วนของหนึ่ง

# %%
new_table_nueng =  data_alldb[['RowKey','phone','urine']] #เลือกคอลัมม์ที่ต้องการ
new_table_nueng #แสดงค่า
# Out:
#                                          RowKey             phone  \
# 0                                           NaN               NaN
# 1          136FD222-FD9F-4E54-AE1F-7282A276B085        iPhone10,4
# 2      1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png               NaN
# 3          2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE        iPhone13,4
# 4          45197AF7-7CB4-470C-9ABB-37C092BD6B21        iPhone13,4
# ...                                         ...               ...
# 40030      6B5FA20F-190E-4021-8547-C12308024C6C        iPhone13,4
# 40031      F48C51C0-A345-40D6-93F4-46213267E1B1        iPhone10,5
# 40032      A986BDAA-6D7C-4017-8E62-A3C104E946B9        iPhone13,4
# 40033                            bbuogxulur.png  Samsung SM-A115F
# 40034                            zttpqogiso.png  Samsung SM-A115F
#
#                  urine
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3      ปกติ (เหลืองใส)
# 4      ปกติ (เหลืองใส)
# ...                ...
# ...

# %%
new_table_nueng.isnull().any() #ตรวจดูค่า missing
# Out:
# RowKey    True
# phone     True
# urine     True
# dtype: bool

# %%
new_table_nueng_drop = new_table_nueng.dropna() #.dropna เพื่อกำจัดค่า missing ออก
new_table_nueng_drop
# Out:
#                                      RowKey              phone  \
# 3      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE         iPhone13,4
# 4      45197AF7-7CB4-470C-9ABB-37C092BD6B21         iPhone13,4
# 6      538F4D59-A921-46BF-82B0-E6834F98957E         iPhone13,4
# 9      9AF8428C-0616-47DE-AB4C-54F31EA31979         iPhone13,4
# 10     B7C1D24C-8090-4C2F-BC04-7CC4D09663DC         iPhone13,4
# ...                                     ...                ...
# 40028                        lkwfdvltek.png  Samsung SM-A307GN
# 40029                        txslrhofvq.png   Samsung SM-N935F
# 40031  F48C51C0-A345-40D6-93F4-46213267E1B1         iPhone10,5
# 40032  A986BDAA-6D7C-4017-8E62-A3C104E946B9         iPhone13,4
# 40034                        zttpqogiso.png   Samsung SM-A115F
#
#                  urine
# 3      ปกติ (เหลืองใส)
# 4      ปกติ (เหลืองใส)
# 6      ปกติ (เหลืองใส)
# 9      ปกติ (เหลืองใส)
# 10     ปกติ (เหลืองใส)
# ...                ...
# 40028  ปกติ (เหลืองใส)
# ...

# %%
new_table_nueng_drop.isnull().any() #ตรวจดูค่า missing
# Out:
# RowKey    False
# phone     False
# urine     False
# dtype: bool

# %%
new_table_nueng_drop
# Out:
#                                      RowKey              phone  \
# 3      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE         iPhone13,4
# 4      45197AF7-7CB4-470C-9ABB-37C092BD6B21         iPhone13,4
# 6      538F4D59-A921-46BF-82B0-E6834F98957E         iPhone13,4
# 9      9AF8428C-0616-47DE-AB4C-54F31EA31979         iPhone13,4
# 10     B7C1D24C-8090-4C2F-BC04-7CC4D09663DC         iPhone13,4
# ...                                     ...                ...
# 40028                        lkwfdvltek.png  Samsung SM-A307GN
# 40029                        txslrhofvq.png   Samsung SM-N935F
# 40031  F48C51C0-A345-40D6-93F4-46213267E1B1         iPhone10,5
# 40032  A986BDAA-6D7C-4017-8E62-A3C104E946B9         iPhone13,4
# 40034                        zttpqogiso.png   Samsung SM-A115F
#
#                  urine
# 3      ปกติ (เหลืองใส)
# 4      ปกติ (เหลืองใส)
# 6      ปกติ (เหลืองใส)
# 9      ปกติ (เหลืองใส)
# 10     ปกติ (เหลืองใส)
# ...                ...
# 40028  ปกติ (เหลืองใส)
# ...

# %%
df = pd.DataFrame(new_table_nueng_drop) #เรียกดูชนิดแต่ละคอลัมม์
df.dtypes
# Out:
# RowKey    object
# phone     object
# urine     object
# dtype: object

# %%
new_table_nueng_drop['RowKey'] = new_table_nueng_drop['RowKey'].astype(str) #เปลี่ยนคอลัมม์ RowKey ให้เป็น string
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
type(new_table_nueng_drop.iloc[0,0]) #ดูชนิดของแถวที่ 0 คอลัมม์ที่ 0 คือ ข้อมูลตัวแรกในข้อมูล RowKey ว่าคอลัมม์นั้นเป็นชนิดอะไร
# Out:
# str

# %%
new_table_nueng_drop['phone'] = new_table_nueng_drop['phone'].astype(str) #เปลี่ยนคอลัมม์ phone ให้เป็น string
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
type(new_table_nueng_drop.iloc[0,1]) #ดูชนิดของแถวที่ 0 คอลัมม์ที่ 1 คือ ข้อมูลตัวแรกในข้อมูล phone ว่าคอลัมม์นั้นเป็นชนิดอะไร
# Out:
# str

# %%
new_table_nueng_drop['urine'] = new_table_nueng_drop['urine'].astype(str) #เปลี่ยนคอลัมม์ phone ให้เป็น string
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
type(new_table_nueng_drop.iloc[0,2]) #ดูชนิดของแถวที่ 0 คอลัมม์ที่ 2 คือ ข้อมูลตัวแรกในข้อมูล phone ว่าคอลัมม์นั้นเป็นชนิดอะไร
# Out:
# str
