# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/data0605.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import panda เพื่อจัดการตาราง
import os

# %%
from google.colab import drive #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
drive.mount('/content/drive') 
path = '/content/drive/My Drive/data_jknow' #เชื่อมกับไดร์ฟ
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์'
# /content

# %%
data_file_path = os.path.join(path,'data.xlsx') 
data = pd.read_excel(data_file_path)

# %%
data
# Out:
#                   ประทับเวลา                    ที่อยู่อีเมล  เพศ ระดับชั้น   \
# 0    2022-05-03 17:12:27.643    phimphxapsrrupkaea@gmail.com  2.0          1
# 1    2022-05-03 17:12:54.699  pinyaphat.saenverm48@gmail.com  2.0          1
# 2    2022-05-03 17:13:06.025           Wanatda.001@gmail.com  2.0          1
# 3    2022-05-03 17:13:11.296         chanisarg0363@gmail.com  2.0          0
# 4    2022-05-03 17:13:26.276         sirada.121618@gmail.com  2.0          1
# ...                      ...                             ...  ...        ...
# 3142 2022-05-06 14:54:31.022                463031@wsk.ac.th  2.0          1
# 3143 2022-05-06 15:26:00.512          kwannapa7547@gmail.com  2.0          1
# 3144 2022-05-06 15:38:54.915             chanap273@gmail.com  1.0          1
# 3145 2022-05-06 15:47:57.241           sasikan7562@gmail.com  2.0          0
# 3146 2022-05-06 15:49:45.061                  38406@rr.ac.th  2.0          1
#
# ...

# %%
set(data['โรงเรียนอยู่ในจังหวัด'])
# Out:
# {'-',
#  nan,
#  'กทม',
#  'กทม.',
#  'กมม.',
#  'กระบี่',
#  'กรุงเทพ',
#  'กรุงเทพ ',
#  'กรุงเทพ ปริมณฑล',
#  'กรุงเทพม',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานครฯ',
#  'กรุงเทพฯ',
#  'กรุงเทพฯ.',
#  'กรุงเทพฯ\u200b',
#  'กรุงเทพๆ',
#  'กรุงเทพ\u200b',
#  'กรุงเทพ\u200bมหานคร',
#  'กรุงเทพ\u200bมหานคร\u200b',
#  'กรุ่งเทพ',
#  'กาญจนบุรี',
#  'กาญจนบุรี\u200b',
#  'กาฬสิ',
#  'กาฬสินธุ์',
#  'กาฬสินธ์ุ',
#  'กำเเพงเพชร',
#  'กำแพงเพชร',
#  'ขอนเเก่น',
#  'ขอนแก่น',
#  'ขอนแก่น ',
#  'ขอนแก่น\u200b',
#  'จ.ปัตตานี',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จ.ร้อยเอ็ด',
#  'จ.อุทัยธานี',
#  'จังหวัดกาญจนบุรี',
#  'จังหวัดขอนแก่น',
#  'จังหวัดชลบุรี',
#  'จังหวัดชัยภูมิ',
#  'จังหวัดน่าน',
#  'จังหวัดพัทลุง',
#  'จังหวัดพิษณุโลก',
#  'จังหวัดมหาสารคาม',
#  'จังหวัดร้อยเอ็ด',
#  'จังหวัดศรีสะเกษ',
#  'จังหวัดสงขลา',
#  'จังหวัดสระแก้ว',
#  'จังหวัดอุทัยธานี',
#  'จังหวัดอุบลราชธานี',
#  'จังหวัดเชียงราย',
#  'จังหวัดเชียงใหม่',
#  'จังหวัดเพชรบูรณ์',
#  'จังหวัดแพร่',
# ...

# %%
data['โรงเรียนอยู่ในจังหวัด'].replace({'-':'0', 
 'nan':'0',
 'กทม':'69',
 'กทม.':'69',
 'กมม.':'69',
 'กระบี่':'45',
 'กรุงเทพ':'69',
 'กรุงเทพ ':'69',
 'กรุงเทพ ปริมณฑล':'69',
 'กรุงเทพม':'69',
 'กรุงเทพมหานคร':'69',
 'กรุงเทพมหานครฯ':'69',
 'กรุงเทพฯ':'69',
 'กรุงเทพฯ.':'69',
 'กรุงเทพฯ\u200b':'69',
 'กรุงเทพๆ':'69',
 'กรุงเทพ\u200b':'69',
 'กรุงเทพ\u200bมหานคร':'69',
 'กรุงเทพ\u200bมหานคร\u200b':'69',
 'กรุ่งเทพ':'69',
 'กาญจนบุรี':'3',
 'กาญจนบุรี\u200b':'3',
 'กาฬสิ':'28',
 'กาฬสินธุ์':'28',
 'กาฬสินธ์ุ':'28',
 'กำเเพงเพชร':'22',
 'กำแพงเพชร':'22',
 'ขอนเเก่น':'15',
 'ขอนแก่น':'15',
 'ขอนแก่น ':'15',
 'ขอนแก่น\u200b':'15',
 'จ.ปัตตานี':'68',
 'จ.ภูเก็ต':'76',
 'จ.ราชบุรี':'42',
 'จ.ร้อยเอ็ด':'23',
 'จ.อุทัยธานี':'29',
 'จังหวัดกาญจนบุรี':'3',
 'จังหวัดขอนแก่น':'15',
 'จังหวัดชลบุรี':'50',
 'จังหวัดชัยภูมิ':'7',
 'จังหวัดน่าน':'13',
 'จังหวัดพัทลุง':'58',
 'จังหวัดพิษณุโลก':'16',
 'จังหวัดมหาสารคาม':'41',
 'จังหวัดร้อยเอ็ด':'23',
 'จังหวัดศรีสะเกษ':'21',
 'จังหวัดสงขลา':'26',
 'จังหวัดสระแก้ว':'27',
 'จังหวัดอุทัยธานี':'29',
 'จังหวัดอุบลราชธานี':'5',
 'จังหวัดเชียงราย':'12',
 'จังหวัดเชียงใหม่':'2',
 'จังหวัดเพชรบูรณ์':'9',
 'จังหวัดแพร่':'31',
 'จังหวัด\u200b:นนทบุรี\u200b':'75',
 'จังหวัด\u200bนนทบุรี\u200b':'75',
 'จันทบุรี':'33',
 'จันทบุรี\u200b':'33',
 'ฉะเชิง':' ',
 'ฉะเชิงเทรา':'40',
 'ฉะเชิงเทรา\u200b':'40',
 'ชลบุ':'50',
 'ชลบุรี':'50',
 'ชลบุรี\u200b':'50',
 'ชลยุรี':'50',
 'ชัยนาท':'65',
 'ชัยภ':'7',
 'ชัยภูมิ':'7',
 'ชัยภูมิภักดีชุมพล':'7',
 'ชัยภูมิ\u200b':'7',
 'ชุมพร':'37',
 'ตรัง':'43',
 'ตราด':'62',
 'ตาก':'4',
 'ทุ่งสง':'18',
 'นครนายก':'67',
 'นครปฐม':'66',
 'นครพนม':'38',
 'นครราชสีมา':'1',
 'นครราชสีมา\u200b':'1',
 'นครศรี':'38',
 'นครศรีธรรมราช':'18',
 'นครศรีธรรมราช ':'18',
 'นครศรีธรรมราช\u200b':'18',
 'นครศรึธรรมราช':'18',
 'นครสวรรค?':'20',
 'นครสวรรค์':'20',
 'นครสวรรค์\u200b':'20',
 'นนทบุรี':'75',
 'นนทบุรี ':'75',
 'นนทุง':'75',
 'นราธิวาส':'49',
 'น่าน':'13',
 'บึงกาฬ':'52',
 'บุรีรัมย์':'17',
 'บุรีรัมย์ ':'17',
 'บุรีรัมย์\u200b':'17',
 'ปทุมธานี':'70',
 'ปทุมธานี\u200b':'70',
 'ปทุ่มธานี':'70',
 'ประจวบคีรีขันธ์':'32',
 'ประจวบคีรีขันธ์ท':'32',
 'ประถมปรีดาภรณ์':'32',
 'ปราจีนบุรี':'44',
 'ปัตตาน':'68',
 'ปัตตานี':'68',
 'ปัตตานี\u200b':'68',
 'พระนครศรีอยุธยา':'63',
 'พระ\u200bนคร\u200bศรี\u200bอยุธยา\u200b':'63',
 'พะเยา':'34',
 'พังงา':'53',
 'พัทลุ':'58',
 'พัทลุง':'58',
 'พัทลุง\u200b':'58',
 'พิจิตร':'46',
 'พิษณุโลก':'16',
 'พิษณุโลก\u200b':'16',
 'ภูเก':'76',
 'ภูเก็ต':'76',
 'ภูเขียว':'7',
 'มหาสารคาม':'41',
 'มหาสารคาม\u200b':'41',
 'มุกดาหาร':'51',
 'ยะลา':'47',
 'ยะลา\u200b':'47',
 'ยโสธร':'54',
 'ระนอง':'59',
 'ระยอง':'57',
 'ราชบุรี':'42',
 'ราชบุรี\u200b':'42',
 'ร้อนเอ':'23',
 'ร้อยเอ':'23',
 'ร้อยเอ็ด':'23',
 'ร้อยเอ็ด\u200b':'23',
 'ลพบุรี':'36',
 'ลำปาง':'10',
 'ลำพูน':'48',
 'ลำพูร':'48',
 'วังหิน':'21',
 'ศรีสะเก':'21',
 'ศรีสะเกษ':'21',
 'ศรีสะเกษ\u200b':'21',
 'ศรีสำราญ':'21',
 'สกลนคร':'19',
 'สกลนคร\u200b':'19',
 'สง':'26',
 'สงขลา':'26',
 'สตรีอิสลามวิทยามูลนิธิ':'47',
 'สตูล':'64',
 'สป.':'71',
 'สมุทรปราการ':'71',
 'สมุทรสงคราม':'77',
 'สมุทรสาคร':'73',
 'สมุทร\u200bปราการ\u200b':'71',
 'สระบุรี':'56',
 'สระบุรี\u200b':'56',
 'สระเเก้ว':'27',
 'สระแก้ว':'27',
 'สิงห์บุรี':'74',
 'สิงห์บุรี\u200b':'74',
 'สุพรรณบุรี':'39',
 'สุพรรณบุรี\u200b':'39',
 'สุมทรปราการ':'71',
 'สุร':'6',
 'สุราษฎร์ธานี':'6',
 'สุราษฏร์ธานี':'6',
 'สุราษร์ฎธานี':'6',
 'สุริน':'24',
 'สุรินทร':'24',
 'สุรินทร์':'24',
 'สุรินทร์\u200b':'24',
 'สุโขทัย':'30',
 'หนองคาย':'61',
 'หนองจอก':'69',
 'หนองบัวลำภู':'55',
 'อยุธยา':'63',
 'อำนาจเจริญ':'60',
 'อุดรธานี':'11',
 'อุต':'25',
 'อุตรดิตถ?':'25',
 'อุตรดิตถ์':'25',
 'อุตรดิตถ์\u200b':'25',
 'อุทัยธานี':'29',
 'อุบลราขธานี':'5',
 'อุบลราชธานี':'5',
 'อุบลราชธานี\u200b':'5',
 'อุยลอุบลราชธานี':'5',
 'อ่างทอง':'72',
 'เขียงใหม่':'2',
 'เชียงรา':'12',
 'เชียงราย':'12',
 'เชียงใหม่':'2',
 'เชียงใหม่\u200b':'2',
 'เพชรบุรี':'35',
 'เพชรบูรณ์':'9',
 'เลน':'14',
 'เลย':'14',
 'เเพร่':'31',
 'เเม่ฮ่องสอน':'8',
 'แพร่':'31',
 'แพร่\u200b':'31',
 'แม่ฮ':'8',
 'แม่ฮ่องสอน':'8',
 'โรงเรียนสิงหพาหุ"ประสานมิตรอุปถัมภ์':'74'},inplace=True)

# %%
data[data['โรงเรียนอยู่ในจังหวัด']=='69']
# Out:
#                   ประทับเวลา                ที่อยู่อีเมล  เพศ ระดับชั้น   \
# 3    2022-05-03 17:13:11.296     chanisarg0363@gmail.com  2.0          0
# 27   2022-05-03 17:17:55.707  banyaphonbok2547@gmail.com  1.0          1
# 47   2022-05-03 17:20:39.103         nan099009@gmail.com  2.0          1
# 71   2022-05-03 17:23:20.372      sunida121159@gmail.com  2.0          1
# 95   2022-05-03 17:27:17.963         loyalx123@gmail.com  1.0          1
# ...                      ...                         ...  ...        ...
# 3098 2022-05-05 21:42:56.327       alexkung007@gmail.com  1.0          1
# 3116 2022-05-06 01:00:08.589       yarindaaa48@gmail.com  3.0          1
# 3128 2022-05-06 10:53:27.725      ploy.orntipa@gmail.com  2.0          1
# 3131 2022-05-06 11:24:14.618       deenar18488@gmail.com  2.0          1
# 3144 2022-05-06 15:38:54.915         chanap273@gmail.com  1.0          1
#
#                                       โรงเรียน โรงเรียนอยู่ในจังหวัด  \
# ...

# %%
data.to_excel('data.xlsx', encoding='utf-8')
