# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/jknowledge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import panda เพื่อจัดการตาราง
import os

# %%
from google.colab import drive #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
drive.mount('/content/drive') 
path = '/content/drive/My Drive/data_jknow' #เชื่อมกับไดร์ฟ
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์'
# /content

# %%
data_file_path = os.path.join(path,'order_all_270565l.xlsx') 
data = pd.read_excel(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype={value.dtype})

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0     2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1     2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2     2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3     2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4     2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                   ...                         ...  ...              ...
# 8634     2022-05-27 21:10  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635     2022-05-27 22:00             เก็บเงินปลายทาง  ...         ******25
# 8636     2022-05-27 22:00             เก็บเงินปลายทาง  ...         ******25
# 8637     2022-05-27 22:21   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638     2022-05-27 22:43             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                                    float64
# Unnamed: 0.1                                    int64
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                   object
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                              object
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                              float64
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                            object
# วันที่คาดว่าจะทำการจัดส่งสินค้า        datetime64[ns]
# เวลาส่งสินค้า                          datetime64[ns]
# เลขอ้างอิง Parent SKU                         float64
# ชื่อสินค้า                                     object
# เลขอ้างอิง SKU (SKU Reference No.)            float64
# ชื่อตัวเลือก                                   object
# ราคาตั้งต้น                                     int64
# ราคาขาย                                         int64
# จำนวน                                           int64
# ราคาขายสุทธิ                                    int64
# ส่วนลดจาก Shopee                                int64
# โค้ดส่วนลดชำระโดยผู้ขาย                         int64
# โค้ด Coins Cashback                             int64
# โค้ดส่วนลดชำระโดย Shopee                        int64
# โค้ดส่วนลด                                     object
# เข้าร่วมแคมเปญ bundle deal หรือไม่             object
# ส่วนลด bundle deal ชำระโดยผู้ขาย                int64
# ส่วนลด bundle deal ชำระโดย Shopee               int64
# ส่วนลดจากการใช้เหรียญ                           int64
# ส่วนลดทั้งหมดจากบัตรเครดิต                      int64
# ค่าคอมมิชชั่น                                   int64
# Transaction Fee                                 int64
# ต้นทุนขายหักคูปองและcoin                        int64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ                      int64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ             int64
# ค่าจัดส่งสินค้าคืน                              int64
# ค่าบริการ                                       int64
# จำนวนเงินทั้งหมด                               object
# ค่าจัดส่งโดยประมาณ                              int64
# ชื่อผู้รับ                                     object
# หมายเลขโทรศัพท์                                object
# หมายเหตุจากผู้ซื้อ                             object
# ที่อยู่ในการจัดส่ง                             object
# ประเทศ                                         object
# จังหวัด                                        object
# เขต/อำเภอ                                      object
# รหัสไปรษณีย์                                    int64
# ประเภทคำสั่งซื้อ                              float64
# เวลาที่ทำการสั่งซื้อสำเร็จ             datetime64[ns]
# บันทึก                                        float64
# dtype: object

# %%
data['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(data['วันที่ทำการสั่งซื้อ'],format="%Y-%m-%d") 
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#         เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0     2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1     2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2     2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3     2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4     2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                   ...                         ...  ...              ...
# 8634     2022-05-27 21:10  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635     2022-05-27 22:00             เก็บเงินปลายทาง  ...         ******25
# 8636     2022-05-27 22:00             เก็บเงินปลายทาง  ...         ******25
# 8637     2022-05-27 22:21   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638     2022-05-27 22:43             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                                    float64
# Unnamed: 0.1                                    int64
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                   object
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                              object
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                              float64
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                            object
# วันที่คาดว่าจะทำการจัดส่งสินค้า        datetime64[ns]
# เวลาส่งสินค้า                          datetime64[ns]
# เลขอ้างอิง Parent SKU                         float64
# ชื่อสินค้า                                     object
# เลขอ้างอิง SKU (SKU Reference No.)            float64
# ชื่อตัวเลือก                                   object
# ราคาตั้งต้น                                     int64
# ราคาขาย                                         int64
# จำนวน                                           int64
# ราคาขายสุทธิ                                    int64
# ส่วนลดจาก Shopee                                int64
# โค้ดส่วนลดชำระโดยผู้ขาย                         int64
# โค้ด Coins Cashback                             int64
# โค้ดส่วนลดชำระโดย Shopee                        int64
# โค้ดส่วนลด                                     object
# เข้าร่วมแคมเปญ bundle deal หรือไม่             object
# ส่วนลด bundle deal ชำระโดยผู้ขาย                int64
# ส่วนลด bundle deal ชำระโดย Shopee               int64
# ส่วนลดจากการใช้เหรียญ                           int64
# ส่วนลดทั้งหมดจากบัตรเครดิต                      int64
# ค่าคอมมิชชั่น                                   int64
# Transaction Fee                                 int64
# ต้นทุนขายหักคูปองและcoin                        int64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ                      int64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ             int64
# ค่าจัดส่งสินค้าคืน                              int64
# ค่าบริการ                                       int64
# จำนวนเงินทั้งหมด                               object
# ค่าจัดส่งโดยประมาณ                              int64
# ชื่อผู้รับ                                     object
# หมายเลขโทรศัพท์                                object
# หมายเหตุจากผู้ซื้อ                             object
# ที่อยู่ในการจัดส่ง                             object
# ประเทศ                                         object
# จังหวัด                                        object
# เขต/อำเภอ                                      object
# รหัสไปรษณีย์                                    int64
# ประเภทคำสั่งซื้อ                              float64
# เวลาที่ทำการสั่งซื้อสำเร็จ             datetime64[ns]
# บันทึก                                        float64
# dtype: object

# %%
data['เวลาการชำระสินค้า'] = pd.to_datetime(data['เวลาการชำระสินค้า'],format="%Y-%m-%d",errors='coerce')
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0    2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1    2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2    2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3    2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4    2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                  ...                         ...  ...              ...
# 8634 2022-05-27 21:10:00  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8636 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8637 2022-05-27 22:21:00   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638 2022-05-27 22:43:00             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(data['เวลาที่ทำการสั่งซื้อสำเร็จ'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0    2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1    2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2    2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3    2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4    2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                  ...                         ...  ...              ...
# 8634 2022-05-27 21:10:00  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8636 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8637 2022-05-27 22:21:00   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638 2022-05-27 22:43:00             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data['วันที่คาดว่าจะทำการจัดส่งสินค้า'] = pd.to_datetime(data['วันที่คาดว่าจะทำการจัดส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0    2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1    2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2    2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3    2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4    2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                  ...                         ...  ...              ...
# 8634 2022-05-27 21:10:00  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8636 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8637 2022-05-27 22:21:00   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638 2022-05-27 22:43:00             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data['เวลาส่งสินค้า'] = pd.to_datetime(data['เวลาส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0    2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1    2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2    2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3    2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4    2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                  ...                         ...  ...              ...
# 8634 2022-05-27 21:10:00  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8636 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8637 2022-05-27 22:21:00   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638 2022-05-27 22:43:00             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data.dtypes
# Out:
# Unnamed: 0                                    float64
# Unnamed: 0.1                                    int64
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                   object
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                      datetime64[ns]
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                              float64
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                            object
# วันที่คาดว่าจะทำการจัดส่งสินค้า        datetime64[ns]
# เวลาส่งสินค้า                          datetime64[ns]
# เลขอ้างอิง Parent SKU                         float64
# ชื่อสินค้า                                     object
# เลขอ้างอิง SKU (SKU Reference No.)            float64
# ชื่อตัวเลือก                                   object
# ราคาตั้งต้น                                     int64
# ราคาขาย                                         int64
# จำนวน                                           int64
# ราคาขายสุทธิ                                    int64
# ส่วนลดจาก Shopee                                int64
# โค้ดส่วนลดชำระโดยผู้ขาย                         int64
# โค้ด Coins Cashback                             int64
# โค้ดส่วนลดชำระโดย Shopee                        int64
# โค้ดส่วนลด                                     object
# เข้าร่วมแคมเปญ bundle deal หรือไม่             object
# ส่วนลด bundle deal ชำระโดยผู้ขาย                int64
# ส่วนลด bundle deal ชำระโดย Shopee               int64
# ส่วนลดจากการใช้เหรียญ                           int64
# ส่วนลดทั้งหมดจากบัตรเครดิต                      int64
# ค่าคอมมิชชั่น                                   int64
# Transaction Fee                                 int64
# ต้นทุนขายหักคูปองและcoin                        int64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ                      int64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ             int64
# ค่าจัดส่งสินค้าคืน                              int64
# ค่าบริการ                                       int64
# จำนวนเงินทั้งหมด                               object
# ค่าจัดส่งโดยประมาณ                              int64
# ชื่อผู้รับ                                     object
# หมายเลขโทรศัพท์                                object
# หมายเหตุจากผู้ซื้อ                             object
# ที่อยู่ในการจัดส่ง                             object
# ประเทศ                                         object
# จังหวัด                                        object
# เขต/อำเภอ                                      object
# รหัสไปรษณีย์                                    int64
# ประเภทคำสั่งซื้อ                              float64
# เวลาที่ทำการสั่งซื้อสำเร็จ             datetime64[ns]
# บันทึก                                        float64
# dtype: object

# %%
set(data['ชื่อสินค้า'])
# Out:
# {'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'E-Book สายแพทย์-วิทย์สุขภาพ',
#  'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.',
#  'E-Book เตรียมสอบ Netsat',
#  'E-Book เตรียมสอบครู',
#  'E-Book เตรียมสอบวิศวะ',
#  'E-book สรุป ม.ปลาย',
#  'E-book เตรียมสอบ ท้องถิ่น ภาค ข.',
#  'E-book เตรียมสอบ ม.ปลาย',
#  'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 65 ฟรี! คอร์สติว 40 ชม.',
#  'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
#  'หนังสือสมรรถนะ มข.',
#  'หนังสือสรุปม.ปลาย Tcas',
#  'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 66-67 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.[ส่งฟรีไม่ง้อโค้ด]',
#  'หนังสือสามัญ คณิตศาสตร์',
#  'หนังสือสามัญ ชีววิทยา',
#  'หนังสือสามัญ ฟิสิกส์',
#  'หนังสือสามัญ ภาษาอังกฤษ',
#  'หนังสือสามัญ ภาษาไทย + สังคม',
#  'หนังสือสามัญ เคมี',
#  'หนังสือสายแพทย์-วิทย์สุขภาพ',
#  'หนังสืออิเล็กทรอนิกส์ เตรียมสอบ สำหรับ ม.ปลาย',
#  'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.',
#  'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65',
#  'หนังสือเตรียมสอบ Netsat',
#  'หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.',
#  'หนังสือเตรียมสอบ ก.พ.',
#  'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม.',
#  'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง',
#  'หนังสือเตรียมสอบครู',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
#  'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
#  'หนังสือเตรียมสอบพยาบาล',
#  'หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง',
#  'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
#  'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3',
#  'หนังสือเตรียมสอบวิศวะ',
#  'หนังสือแพทย์-ทันตะ'}

# %%
data['ชื่อสินค้า'].replace ({'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ':'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ ',
 'E-Book สายแพทย์-วิทย์สุขภาพ':'E-Book สายแพทย์-วิทย์สุขภาพ',
 'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
 'E-Book เตรียมสอบ Netsat':'E-Book เตรียมสอบ Netsat',
 'E-Book เตรียมสอบครู':'E-Book เตรียมสอบครู',
 'E-Book เตรียมสอบวิศวะ':'E-Book เตรียมสอบวิศวะ',
 'E-book สรุป ม.ปลาย':'E-book สรุป ม.ปลาย',
 'E-book เตรียมสอบ ท้องถิ่น ภาค ข.':'E-book เตรียมสอบ ท้องถิ่น ภาค ข',
 'E-book เตรียมสอบ ม.ปลาย':'E-book สรุป ม.ปลาย',
 'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 65 ฟรี! คอร์สติว 40 ชม.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือสมรรถนะ มข.':'หนังสือสมรรถนะ มข.',
 'หนังสือสรุปม.ปลาย Tcas':'หนังสือสรุปม.ปลาย Tcas',
 'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 66-67 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.[ส่งฟรีไม่ง้อโค้ด]':'หนังสือสรุปม.ปลาย Tcas',
 'หนังสือสามัญ คณิตศาสตร์':'หนังสือสามัญ คณิตศาสตร์',
 'หนังสือสามัญ ชีววิทยา':'หนังสือสามัญ ชีววิทยา',
 'หนังสือสามัญ ฟิสิกส์':'หนังสือสามัญ ฟิสิกส์',
 'หนังสือสามัญ ภาษาอังกฤษ':'หนังสือสามัญ ภาษาอังกฤษ',
 'หนังสือสามัญ ภาษาไทย + สังคม':'หนังสือสามัญ ภาษาไทย + สังคม',
 'หนังสือสามัญ เคมี':'หนังสือสามัญ เคมี',
 'หนังสือสายแพทย์-วิทย์สุขภาพ':'หนังสือสายแพทย์-วิทย์สุขภาพ',
 'หนังสืออิเล็กทรอนิกส์ เตรียมสอบ สำหรับ ม.ปลาย':'E-book สรุป ม.ปลาย',
 'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
 'หนังสือเตรียมสอบ Netsat':'หนังสือเตรียมสอบ Netsat',
 'หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
 'หนังสือเตรียมสอบ ก.พ.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม.':'หนังสือแพทย์-ทันตะ',
 'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบครู',
 'หนังสือเตรียมสอบครู':'หนังสือเตรียมสอบครู',
 'หนังสือเตรียมสอบท้องถิ่น ภาค ก.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
 'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)':'หนังสือเตรียมสอบท้องถิ่น ภาค ข. (นักทรัพยากรบุคคล)',
 'หนังสือเตรียมสอบพยาบาล':'หนังสือเตรียมสอบพยาบาล',
 'หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
 'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร',
 'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3':'หนังสือเตรียมสอบวิศวะ',
 'หนังสือเตรียมสอบวิศวะ':'หนังสือเตรียมสอบวิศวะ',
 'หนังสือแพทย์-ทันตะ':'หนังสือแพทย์-ทันตะ'},inplace=True)

# %%
data
# Out:
#       Unnamed: 0  Unnamed: 0.1 หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0            0.0             0    211001PFVP7NFF       สำเร็จแล้ว
# 1            1.0             1    211001Q88N1WU9       สำเร็จแล้ว
# 2            2.0             2    211002QHGXFKGH       สำเร็จแล้ว
# 3            3.0             3    211002R5QQRQNB       สำเร็จแล้ว
# 4            4.0             4    211002RMMQ9NK1       สำเร็จแล้ว
# ...          ...           ...               ...              ...
# 8634         NaN          8634    220527AF2E914P    ที่ต้องจัดส่ง
# 8635         NaN          8635    220527AG81W1CK    ที่ต้องจัดส่ง
# 8636         NaN          8636    220527AG81W1CK    ที่ต้องจัดส่ง
# 8637         NaN          8637    220527AHWM6874    ที่ต้องจัดส่ง
# 8638         NaN          8638    220527AJMH0UUT       ยกเลิกแล้ว
#
#                          เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 8634                                             NaN
# 8635                                             NaN
# 8636                                             NaN
# 8637                                             NaN
# 8638  ยกเลิกโดยผู้ซื้อ เหตุผล : อื่น ๆ หรือเปลี่ยนใจ
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN         worapan25678 2021-10-01 14:36:00
# 1                             NaN          uchissstore 2021-10-01 21:52:00
# 2                             NaN            airfan777 2021-10-02 00:38:00
# 3                             NaN      copyrighfreezer 2021-10-02 06:39:00
# 4                             NaN             toonny23 2021-10-02 11:06:00
# ...                           ...                  ...                 ...
# 8634                          NaN        buangam232529 2022-05-27 21:09:00
# 8635                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8636                          NaN          kanyanat_44 2022-05-27 21:30:00
# 8637                          NaN             nskchcnk 2022-05-27 22:00:00
# 8638                          NaN       santipappinjai 2022-05-27 22:13:00
#
#        เวลาการชำระสินค้า          ช่องทางการชำระเงิน  ...  หมายเลขโทรศัพท์  \
# 0    2021-10-01 14:37:00        บัตรเครดิต/บัตรเดบิต  ...         ******43
# 1    2021-10-01 22:22:00             เก็บเงินปลายทาง  ...         ******72
# 2    2021-10-02 01:08:00             เก็บเงินปลายทาง  ...         ******02
# 3    2021-10-02 07:10:00             เก็บเงินปลายทาง  ...         ******02
# 4    2021-10-02 11:36:00             เก็บเงินปลายทาง  ...         ******44
# ...                  ...                         ...  ...              ...
# 8634 2022-05-27 21:10:00  ShopeePay - ตัดบัญชีธนาคาร  ...         ******93
# 8635 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8636 2022-05-27 22:00:00             เก็บเงินปลายทาง  ...         ******25
# 8637 2022-05-27 22:21:00   โอน/ชำระผ่านช่องทางธนาคาร  ...         ******44
# 8638 2022-05-27 22:43:00             เก็บเงินปลายทาง  ...         ******00
#
#      หมายเหตุจากผู้ซื้อ                                 ที่อยู่ในการจัดส่ง  \
# 0                   NaN  ******ากลางบ้าน ม.5) ต.บ้านหว้า  อำเภอเมืองขอน...
# 1                   NaN  ******บ้านหนองไผ่ 40000 อำเภอเมืองขอนแก่น จังห...
# 2                   NaN      ******ยะหา จ.ยะลา อำเภอยะหา จังหวัดยะลา 95120
# 3                   NaN  ******บ้านเจดีย์แม่ครัว อยู่ใกล้ๆเซเว่น หลังร้...
# 4                   NaN  ******องคาย ต.จอหอ อำเภอเมืองนครราชสีมา จังหวั...
# ...                 ...                                                ...
# 8634                NaN  291/2 หมู่9 ต.หนองหญ้าปล้อง อ.หนองหญ้าปล้อง จ....
# 8635                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8636                NaN  บ้านนางิ้ว หมู่11 ตำบลโพนงาม อำเภอหนองหาน จังห...
# 8637                NaN  126 บ้านใหม่ดอนมูล ต.ควร อำเภอปง จังหวัดพะเยา ...
# 8638                NaN  ******เชียงราย อำเภอเมืองเชียงราย จังหวัดเชียง...
#
#      ประเทศ            จังหวัด             เขต/อำเภอ รหัสไปรษณีย์  \
# 0        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 1        TH     จังหวัดขอนแก่น     อำเภอเมืองขอนแก่น        40000
# 2        TH        จังหวัดยะลา             อำเภอยะหา        95120
# 3        TH   จังหวัดเชียงใหม่          อำเภอสันทราย        50290
# 4        TH  จังหวัดนครราชสีมา  อำเภอเมืองนครราชสีมา        30310
# ...     ...                ...                   ...          ...
# 8634     TH    จังหวัดเพชรบุรี    อำเภอหนองหญ้าปล้อง        76160
# 8635     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8636     TH    จังหวัดอุดรธานี          อำเภอหนองหาน        41130
# 8637     TH       จังหวัดพะเยา               อำเภอปง        56140
# 8638     TH    จังหวัดเชียงราย    อำเภอเมืองเชียงราย        57000
#
#      ประเภทคำสั่งซื้อ  เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0                 NaN         2021-10-02 19:35:00    NaN
# 1                 NaN         2021-10-03 21:38:00    NaN
# 2                 NaN         2021-10-12 07:46:00    NaN
# 3                 NaN         2021-10-09 08:07:00    NaN
# 4                 NaN         2021-10-04 18:50:00    NaN
# ...               ...                         ...    ...
# 8634              NaN                         NaT    NaN
# 8635              NaN                         NaT    NaN
# 8636              NaN                         NaT    NaN
# 8637              NaN                         NaT    NaN
# 8638              NaN                         NaT    NaN
#
# [8639 rows x 56 columns]

# %%
data.to_excel('order_all_270565.xlsx', encoding='utf-8')
