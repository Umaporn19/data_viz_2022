# %% [markdown]
# <a href="https://colab.research.google.com/github/Umaporn19/data_viz_2022/blob/main/jknowledge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #import panda เพื่อจัดการตาราง
import os

# %%
from google.colab import drive #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
drive.mount('/content/drive') 
path = '/content/drive/My Drive/data_jknow' #เชื่อมกับไดร์ฟ
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/data_jknow #ชี้ที่อยู่ของไฟล์'
# /content

# %%
data_file_path = os.path.join(path,'Order_all.xlsx') 
data = pd.read_excel(data_file_path)

# %%
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535    2022-05-03 09:26
# 1                             NaN           ja_kritiiz    2022-05-03 11:30
# 2                             NaN           fern281263    2022-05-03 11:31
# 3                             NaN           aphinyamat    2022-05-03 12:28
# 4                             NaN       krittinjansiri    2022-05-03 12:55
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin    2022-05-11 22:37
# 489                           NaN  jenwitsomboonres090    2022-05-11 22:58
# 490                           NaN          miewty2nair    2022-05-11 23:21
# 491                           NaN           siriyavaan    2022-05-11 23:25
# 492                           NaN         kinkamonkann    2022-05-11 23:35
#
#     เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0    2022-05-03 09:26             SPayLater
# 1    2022-05-03 12:00       เก็บเงินปลายทาง
# 2                   -       เก็บเงินปลายทาง
# 3    2022-05-03 12:58       เก็บเงินปลายทาง
# 4    2022-05-03 13:25       เก็บเงินปลายทาง
# ..                ...                   ...
# 488  2022-05-11 22:38             SPayLater
# 489  2022-05-11 23:28       เก็บเงินปลายทาง
# 490  2022-05-11 23:51       เก็บเงินปลายทาง
# 491  2022-05-11 23:55       เก็บเงินปลายทาง
# 492  2022-05-11 23:36  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0              2022-05-06 14:02    NaN
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3              2022-05-06 15:22    NaN
# 4              2022-05-11 11:39    NaN
# ..                          ...    ...
# 488                         NaN    NaN
# 489                         NaN    NaN
# 490                         NaN    NaN
# 491                         NaN    NaN
# 492                         NaN    NaN
#
# [493 rows x 54 columns]

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                       object
# สถานะการสั่งซื้อ                        object
# เหตุผลในการยกเลิกคำสั่งซื้อ             object
# สถานะการคืนเงินหรือคืนสินค้า           float64
# ชื่อผู้ใช้ (ผู้ซื้อ)                    object
# วันที่ทำการสั่งซื้อ                     object
# เวลาการชำระสินค้า                       object
# ช่องทางการชำระเงิน                      object
# ช่องทางการชำระเงิน (รายละเอียด)_1      float64
# ช่องทางการชำระเงิน (รายละเอียด)_2       object
# ค่าธรรมเนียม (%)                        object
# ตัวเลือกการจัดส่ง                       object
# วิธีการจัดส่ง                           object
# *หมายเลขติดตามพัสดุ                    float64
# วันที่คาดว่าจะทำการจัดส่งสินค้า         object
# เวลาส่งสินค้า                           object
# เลขอ้างอิง Parent SKU                  float64
# ชื่อสินค้า                              object
# เลขอ้างอิง SKU (SKU Reference No.)     float64
# ชื่อตัวเลือก                            object
# ราคาตั้งต้น                            float64
# ราคาขาย                                float64
# จำนวน                                    int64
# ราคาขายสุทธิ                           float64
# ส่วนลดจาก Shopee                       float64
# โค้ดส่วนลดชำระโดยผู้ขาย                float64
# โค้ด Coins Cashback                    float64
# โค้ดส่วนลดชำระโดย Shopee               float64
# โค้ดส่วนลด                              object
# เข้าร่วมแคมเปญ bundle deal หรือไม่      object
# ส่วนลด bundle deal ชำระโดยผู้ขาย       float64
# ส่วนลด bundle deal ชำระโดย Shopee      float64
# ส่วนลดจากการใช้เหรียญ                    int64
# ส่วนลดทั้งหมดจากบัตรเครดิต             float64
# ค่าคอมมิชชั่น                          float64
# Transaction Fee                        float64
# ต้นทุนขายหักคูปองและcoin               float64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ             float64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ    float64
# ค่าจัดส่งสินค้าคืน                     float64
# ค่าบริการ                              float64
# จำนวนเงินทั้งหมด                       float64
# ค่าจัดส่งโดยประมาณ                     float64
# ชื่อผู้รับ                              object
# หมายเลขโทรศัพท์                         object
# หมายเหตุจากผู้ซื้อ                      object
# ที่อยู่ในการจัดส่ง                      object
# ประเทศ                                  object
# จังหวัด                                 object
# เขต/อำเภอ                               object
# รหัสไปรษณีย์                             int64
# ประเภทคำสั่งซื้อ                       float64
# เวลาที่ทำการสั่งซื้อสำเร็จ              object
# บันทึก                                 float64
# dtype: object

# %%
data['วันที่ทำการสั่งซื้อ'] = pd.to_datetime(data['วันที่ทำการสั่งซื้อ'],format="%Y-%m-%d") 
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#     เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0    2022-05-03 09:26             SPayLater
# 1    2022-05-03 12:00       เก็บเงินปลายทาง
# 2                   -       เก็บเงินปลายทาง
# 3    2022-05-03 12:58       เก็บเงินปลายทาง
# 4    2022-05-03 13:25       เก็บเงินปลายทาง
# ..                ...                   ...
# 488  2022-05-11 22:38             SPayLater
# 489  2022-05-11 23:28       เก็บเงินปลายทาง
# 490  2022-05-11 23:51       เก็บเงินปลายทาง
# 491  2022-05-11 23:55       เก็บเงินปลายทาง
# 492  2022-05-11 23:36  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0              2022-05-06 14:02    NaN
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3              2022-05-06 15:22    NaN
# 4              2022-05-11 11:39    NaN
# ..                          ...    ...
# 488                         NaN    NaN
# 489                         NaN    NaN
# 490                         NaN    NaN
# 491                         NaN    NaN
# 492                         NaN    NaN
#
# [493 rows x 54 columns]

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                  float64
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                              object
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                               object
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                           float64
# วันที่คาดว่าจะทำการจัดส่งสินค้า                object
# เวลาส่งสินค้า                                  object
# เลขอ้างอิง Parent SKU                         float64
# ชื่อสินค้า                                     object
# เลขอ้างอิง SKU (SKU Reference No.)            float64
# ชื่อตัวเลือก                                   object
# ราคาตั้งต้น                                   float64
# ราคาขาย                                       float64
# จำนวน                                           int64
# ราคาขายสุทธิ                                  float64
# ส่วนลดจาก Shopee                              float64
# โค้ดส่วนลดชำระโดยผู้ขาย                       float64
# โค้ด Coins Cashback                           float64
# โค้ดส่วนลดชำระโดย Shopee                      float64
# โค้ดส่วนลด                                     object
# เข้าร่วมแคมเปญ bundle deal หรือไม่             object
# ส่วนลด bundle deal ชำระโดยผู้ขาย              float64
# ส่วนลด bundle deal ชำระโดย Shopee             float64
# ส่วนลดจากการใช้เหรียญ                           int64
# ส่วนลดทั้งหมดจากบัตรเครดิต                    float64
# ค่าคอมมิชชั่น                                 float64
# Transaction Fee                               float64
# ต้นทุนขายหักคูปองและcoin                      float64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ                    float64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ           float64
# ค่าจัดส่งสินค้าคืน                            float64
# ค่าบริการ                                     float64
# จำนวนเงินทั้งหมด                              float64
# ค่าจัดส่งโดยประมาณ                            float64
# ชื่อผู้รับ                                     object
# หมายเลขโทรศัพท์                                object
# หมายเหตุจากผู้ซื้อ                             object
# ที่อยู่ในการจัดส่ง                             object
# ประเทศ                                         object
# จังหวัด                                        object
# เขต/อำเภอ                                      object
# รหัสไปรษณีย์                                    int64
# ประเภทคำสั่งซื้อ                              float64
# เวลาที่ทำการสั่งซื้อสำเร็จ                     object
# บันทึก                                        float64
# dtype: object

# %%
data['เวลาการชำระสินค้า'] = pd.to_datetime(data['เวลาการชำระสินค้า'],format="%Y-%m-%d",errors='coerce')
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#       เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0   2022-05-03 09:26:00             SPayLater
# 1   2022-05-03 12:00:00       เก็บเงินปลายทาง
# 2                   NaT       เก็บเงินปลายทาง
# 3   2022-05-03 12:58:00       เก็บเงินปลายทาง
# 4   2022-05-03 13:25:00       เก็บเงินปลายทาง
# ..                  ...                   ...
# 488 2022-05-11 22:38:00             SPayLater
# 489 2022-05-11 23:28:00       เก็บเงินปลายทาง
# 490 2022-05-11 23:51:00       เก็บเงินปลายทาง
# 491 2022-05-11 23:55:00       เก็บเงินปลายทาง
# 492 2022-05-11 23:36:00  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0              2022-05-06 14:02    NaN
# 1                           NaN    NaN
# 2                           NaN    NaN
# 3              2022-05-06 15:22    NaN
# 4              2022-05-11 11:39    NaN
# ..                          ...    ...
# 488                         NaN    NaN
# 489                         NaN    NaN
# 490                         NaN    NaN
# 491                         NaN    NaN
# 492                         NaN    NaN
#
# [493 rows x 54 columns]

# %%
data['เวลาที่ทำการสั่งซื้อสำเร็จ'] = pd.to_datetime(data['เวลาที่ทำการสั่งซื้อสำเร็จ'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#       เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0   2022-05-03 09:26:00             SPayLater
# 1   2022-05-03 12:00:00       เก็บเงินปลายทาง
# 2                   NaT       เก็บเงินปลายทาง
# 3   2022-05-03 12:58:00       เก็บเงินปลายทาง
# 4   2022-05-03 13:25:00       เก็บเงินปลายทาง
# ..                  ...                   ...
# 488 2022-05-11 22:38:00             SPayLater
# 489 2022-05-11 23:28:00       เก็บเงินปลายทาง
# 490 2022-05-11 23:51:00       เก็บเงินปลายทาง
# 491 2022-05-11 23:55:00       เก็บเงินปลายทาง
# 492 2022-05-11 23:36:00  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0           2022-05-06 14:02:00    NaN
# 1                           NaT    NaN
# 2                           NaT    NaN
# 3           2022-05-06 15:22:00    NaN
# 4           2022-05-11 11:39:00    NaN
# ..                          ...    ...
# 488                         NaT    NaN
# 489                         NaT    NaN
# 490                         NaT    NaN
# 491                         NaT    NaN
# 492                         NaT    NaN
#
# [493 rows x 54 columns]

# %%
data['วันที่คาดว่าจะทำการจัดส่งสินค้า'] = pd.to_datetime(data['วันที่คาดว่าจะทำการจัดส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#       เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0   2022-05-03 09:26:00             SPayLater
# 1   2022-05-03 12:00:00       เก็บเงินปลายทาง
# 2                   NaT       เก็บเงินปลายทาง
# 3   2022-05-03 12:58:00       เก็บเงินปลายทาง
# 4   2022-05-03 13:25:00       เก็บเงินปลายทาง
# ..                  ...                   ...
# 488 2022-05-11 22:38:00             SPayLater
# 489 2022-05-11 23:28:00       เก็บเงินปลายทาง
# 490 2022-05-11 23:51:00       เก็บเงินปลายทาง
# 491 2022-05-11 23:55:00       เก็บเงินปลายทาง
# 492 2022-05-11 23:36:00  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0           2022-05-06 14:02:00    NaN
# 1                           NaT    NaN
# 2                           NaT    NaN
# 3           2022-05-06 15:22:00    NaN
# 4           2022-05-11 11:39:00    NaN
# ..                          ...    ...
# 488                         NaT    NaN
# 489                         NaT    NaN
# 490                         NaT    NaN
# 491                         NaT    NaN
# 492                         NaT    NaN
#
# [493 rows x 54 columns]

# %%
data['เวลาส่งสินค้า'] = pd.to_datetime(data['เวลาส่งสินค้า'],format="%Y-%m-%d",errors='ignore')
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#       เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0   2022-05-03 09:26:00             SPayLater
# 1   2022-05-03 12:00:00       เก็บเงินปลายทาง
# 2                   NaT       เก็บเงินปลายทาง
# 3   2022-05-03 12:58:00       เก็บเงินปลายทาง
# 4   2022-05-03 13:25:00       เก็บเงินปลายทาง
# ..                  ...                   ...
# 488 2022-05-11 22:38:00             SPayLater
# 489 2022-05-11 23:28:00       เก็บเงินปลายทาง
# 490 2022-05-11 23:51:00       เก็บเงินปลายทาง
# 491 2022-05-11 23:55:00       เก็บเงินปลายทาง
# 492 2022-05-11 23:36:00  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0           2022-05-06 14:02:00    NaN
# 1                           NaT    NaN
# 2                           NaT    NaN
# 3           2022-05-06 15:22:00    NaN
# 4           2022-05-11 11:39:00    NaN
# ..                          ...    ...
# 488                         NaT    NaN
# 489                         NaT    NaN
# 490                         NaT    NaN
# 491                         NaT    NaN
# 492                         NaT    NaN
#
# [493 rows x 54 columns]

# %%
data.dtypes
# Out:
# หมายเลขคำสั่งซื้อ                              object
# สถานะการสั่งซื้อ                               object
# เหตุผลในการยกเลิกคำสั่งซื้อ                    object
# สถานะการคืนเงินหรือคืนสินค้า                  float64
# ชื่อผู้ใช้ (ผู้ซื้อ)                           object
# วันที่ทำการสั่งซื้อ                    datetime64[ns]
# เวลาการชำระสินค้า                      datetime64[ns]
# ช่องทางการชำระเงิน                             object
# ช่องทางการชำระเงิน (รายละเอียด)_1             float64
# ช่องทางการชำระเงิน (รายละเอียด)_2              object
# ค่าธรรมเนียม (%)                               object
# ตัวเลือกการจัดส่ง                              object
# วิธีการจัดส่ง                                  object
# *หมายเลขติดตามพัสดุ                           float64
# วันที่คาดว่าจะทำการจัดส่งสินค้า        datetime64[ns]
# เวลาส่งสินค้า                          datetime64[ns]
# เลขอ้างอิง Parent SKU                         float64
# ชื่อสินค้า                                     object
# เลขอ้างอิง SKU (SKU Reference No.)            float64
# ชื่อตัวเลือก                                   object
# ราคาตั้งต้น                                   float64
# ราคาขาย                                       float64
# จำนวน                                           int64
# ราคาขายสุทธิ                                  float64
# ส่วนลดจาก Shopee                              float64
# โค้ดส่วนลดชำระโดยผู้ขาย                       float64
# โค้ด Coins Cashback                           float64
# โค้ดส่วนลดชำระโดย Shopee                      float64
# โค้ดส่วนลด                                     object
# เข้าร่วมแคมเปญ bundle deal หรือไม่             object
# ส่วนลด bundle deal ชำระโดยผู้ขาย              float64
# ส่วนลด bundle deal ชำระโดย Shopee             float64
# ส่วนลดจากการใช้เหรียญ                           int64
# ส่วนลดทั้งหมดจากบัตรเครดิต                    float64
# ค่าคอมมิชชั่น                                 float64
# Transaction Fee                               float64
# ต้นทุนขายหักคูปองและcoin                      float64
# ค่าจัดส่งที่ชำระโดยผู้ซื้อ                    float64
# ค่าจัดส่งที่ Shopee ออกให้โดยประมาณ           float64
# ค่าจัดส่งสินค้าคืน                            float64
# ค่าบริการ                                     float64
# จำนวนเงินทั้งหมด                              float64
# ค่าจัดส่งโดยประมาณ                            float64
# ชื่อผู้รับ                                     object
# หมายเลขโทรศัพท์                                object
# หมายเหตุจากผู้ซื้อ                             object
# ที่อยู่ในการจัดส่ง                             object
# ประเทศ                                         object
# จังหวัด                                        object
# เขต/อำเภอ                                      object
# รหัสไปรษณีย์                                    int64
# ประเภทคำสั่งซื้อ                              float64
# เวลาที่ทำการสั่งซื้อสำเร็จ             datetime64[ns]
# บันทึก                                        float64
# dtype: object

# %%
set(data['ชื่อสินค้า'])
# Out:
# {'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.',
#  'E-book หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม. [ส่งฟรีไม่ง้อโค้ด]',
#  'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.',
#  'หนังสือติวสอบท้องถิ่น ภาค ก และเฉลยข้อสอบจริงท้องถิ่น (ภาค ก) 64 ฟรี! คอร์สติว 35 ชม.',
#  'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15',
#  'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.[ส่งฟรีไม่ง้อโค้ด]',
#  'หนังสืออิเล็กทรอนิกส์ เตรียมสอบ สำหรับ ม.ปลาย',
#  'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.',
#  'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65',
#  'หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.',
#  'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม.',
#  'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง',
#  'หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง',
#  'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3',
#  'หนังสือเตรียมสอบเข้าคณะมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน'}

# %%
data['ชื่อสินค้า'].replace ({'E-Book เตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม.':'E-Book เตรียมสอบ Netsat',
 'E-book หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม. [ส่งฟรีไม่ง้อโค้ด]':'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือติวสอบ ก.พ. พร้อมติวและเฉลยข้อสอบจริง ก.พ. (ภาค ก) 64 ฟรี! คอร์สติว 40 ชม.':'หนังสือเตรียมสอบ ก.พ.',
 'หนังสือติวสอบท้องถิ่น ภาค ก และเฉลยข้อสอบจริงท้องถิ่น (ภาค ก) 64 ฟรี! คอร์สติว 35 ชม.':'หนังสือเตรียมสอบท้องถิ่น ภาค ก.',
 'หนังสือสมรรถนะมข. เตรียมสอบโควตามข. สำหรับเด็ก 65-66 Tcas รอบ 2(โควตารับตรง) ฟรีคอร์สติว 15':'หนังสือสมรรถนะ มข',
 'หนังสือสรุปเนื้อหา ม.ปลาย TCAS 65-66 เกณฑ์ใหม่ สสวท. ฟรีคอร์สติว 25 ชม.[ส่งฟรีไม่ง้อโค้ด]':'หนังสือสรุปม.ปลาย Tcas',
 'หนังสืออิเล็กทรอนิกส์ เตรียมสอบ สำหรับ ม.ปลาย':'E-Book รวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือเฉลยละเอียดวิชาสามัญ 64 ฟรี! คอร์สติววิชาสามัญ 64 กว่า 20 ชม.':'หนังสือรวมข้อสอบจริงและเฉลยวิชาสามัญ',
 'หนังสือเตรียมสอบ NETSAT มข. เล่มเดียวครบทั้ง SAT I และ SAT II  ฟรี! คอร์สติว 21 ชม. พิชิต NETSAT มข. 65':'หนังสือเตรียมสอบ Netsat',
 'หนังสือเตรียมสอบ TCAS สำหรับสายแพทย์และวิทยาศาสตร์สุขภาพ ฟรีคอร์สติว 16 ชม.':'หนังสือสายแพทย์-วิทย์สุขภาพ',
 'หนังสือเตรียมสอบ แพทย์-ทันตะ TCAS65-66 ฟรี! คอร์สติวความถนัดแพทย์(กสพท.) ครบทุกพาร์ทกว่า 6ชม.':'หนังสือแพทย์-ทันตะ',
 'หนังสือเตรียมสอบครุศาสตร์/ศึกษาศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี!คอร์สติวเตรียมสอบความถนัดทางวิชาชีพครู กว่า 10 ชั่วโมง':'หนังสือเตรียมสอบครู',
 'หนังสือเตรียมสอบพยาบาลและเฉลย ฟรีคอร์สติว 10 ชั่วโมง':'หนังสือเตรียมสอบพยาบาล',
 'หนังสือเตรียมสอบวิศวกรรมศาสตร์ รวมข้อสอบจริงและเฉลย ฟรี! คอร์สติวเตรียมสอบความถนัดวิศวะ PAT 3':'หนังสือเตรียมสอบวิศวะ',
 'หนังสือเตรียมสอบเข้าคณะมนุษย์ นิติ บริหาร รัฐศาสตร์ การบิน':'หนังสือเตรียมสอบมนุษย์ นิติ บริหาร'},inplace=True)

# %%
data
# Out:
#     หมายเลขคำสั่งซื้อ สถานะการสั่งซื้อ  \
# 0      220503736MW53W       สำเร็จแล้ว
# 1      2205037A5FG1G7        การจัดส่ง
# 2      2205037A7C841X       ยกเลิกแล้ว
# 3      2205037DCK7YAK       สำเร็จแล้ว
# 4      2205037EW4N339       สำเร็จแล้ว
# ..                ...              ...
# 488    220511VK5HVACC    ที่ต้องจัดส่ง
# 489    220511VMA5C0NF    ที่ต้องจัดส่ง
# 490    220512VNKW9R3D    ที่ต้องจัดส่ง
# 491    220512VNTB4W8T    ที่ต้องจัดส่ง
# 492    220512VPCTEBWV    ที่ต้องจัดส่ง
#
#                            เหตุผลในการยกเลิกคำสั่งซื้อ  \
# 0                                                  NaN
# 1                                                  NaN
# 2    ยกเลิกโดยผู้ซื้อ เหตุผล : ต้องการแก้ไขรายละเอี...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 488                                                NaN
# 489                                                NaN
# 490                                                NaN
# 491                                                NaN
# 492                                                NaN
#
#      สถานะการคืนเงินหรือคืนสินค้า ชื่อผู้ใช้ (ผู้ซื้อ) วันที่ทำการสั่งซื้อ  \
# 0                             NaN        sukanybee2535 2022-05-03 09:26:00
# 1                             NaN           ja_kritiiz 2022-05-03 11:30:00
# 2                             NaN           fern281263 2022-05-03 11:31:00
# 3                             NaN           aphinyamat 2022-05-03 12:28:00
# 4                             NaN       krittinjansiri 2022-05-03 12:55:00
# ..                            ...                  ...                 ...
# 488                           NaN  nutthapongrujiwasin 2022-05-11 22:37:00
# 489                           NaN  jenwitsomboonres090 2022-05-11 22:58:00
# 490                           NaN          miewty2nair 2022-05-11 23:21:00
# 491                           NaN           siriyavaan 2022-05-11 23:25:00
# 492                           NaN         kinkamonkann 2022-05-11 23:35:00
#
#       เวลาการชำระสินค้า    ช่องทางการชำระเงิน  \
# 0   2022-05-03 09:26:00             SPayLater
# 1   2022-05-03 12:00:00       เก็บเงินปลายทาง
# 2                   NaT       เก็บเงินปลายทาง
# 3   2022-05-03 12:58:00       เก็บเงินปลายทาง
# 4   2022-05-03 13:25:00       เก็บเงินปลายทาง
# ..                  ...                   ...
# 488 2022-05-11 22:38:00             SPayLater
# 489 2022-05-11 23:28:00       เก็บเงินปลายทาง
# 490 2022-05-11 23:51:00       เก็บเงินปลายทาง
# 491 2022-05-11 23:55:00       เก็บเงินปลายทาง
# 492 2022-05-11 23:36:00  บัตรเครดิต/บัตรเดบิต
#
#      ช่องทางการชำระเงิน (รายละเอียด)_1 ช่องทางการชำระเงิน (รายละเอียด)_2  ...  \
# 0                                  NaN                  Shopee Credit x6  ...
# 1                                  NaN                  Cash on Delivery  ...
# 2                                  NaN                  Cash on Delivery  ...
# 3                                  NaN                  Cash on Delivery  ...
# 4                                  NaN                  Cash on Delivery  ...
# ..                                 ...                               ...  ...
# 488                                NaN                  Shopee Credit x2  ...
# 489                                NaN                  Cash on Delivery  ...
# 490                                NaN                  Cash on Delivery  ...
# 491                                NaN                  Cash on Delivery  ...
# 492                                NaN                Airpay Credit Card  ...
#
#     หมายเลขโทรศัพท์  หมายเหตุจากผู้ซื้อ  \
# 0          ******80  หนังสือ ก.พ ปี 65
# 1          ******90                 NaN
# 2          ******69                 NaN
# 3          ******91                 NaN
# 4          ******83                 NaN
# ..              ...                 ...
# 488        ******60                 NaN
# 489        ******92                 NaN
# 490        ******02                 NaN
# 491        ******36                 NaN
# 492        ******95                 NaN
#
#                                     ที่อยู่ในการจัดส่ง  ประเทศ  \
# 0    ******กุฏโง้ง อ.พนัสนิคม จ.ชลบุรี 20140 อำเภอพ...      TH
# 1    ******4/34-35 หมู่5 ถ.เฉลิมพระเกียรติ ต.รัษฎา ...      TH
# 2    ******ง อำเภอบางสะพาน จังหวัดประจวบคีรีขันธ์ 7...      TH
# 3          ******น อำเภอสีคิ้ว จังหวัดนครราชสีมา 30140      TH
# 4    ******5 , ตำบล เขารูปช้าง อำเภอเมืองสงขลา จังห...      TH
# ..                                                 ...     ...
# 488  156/5 กองพัน สห.ทร. กองทัพเรือองร้อยสารวัตที่1...      TH
# 489  ยอแสง เทวรัตน์พ.นาโพธิ์ ต.ศรีสว่าง.นาโพธิ์ จ.บ...      TH
# 490  คลินิกเชียงของรักษาสัตว์(หมอสันต์) 9/1 ม.11 ต....      TH
# 491  ที่อยู่8/14, ถนนกรุงเกษม, แขวงวัดสามพระยา เขตพ...      TH
# 492  81/316 ซอย รามคำแหง 186 มีนบุรี กรุงเทพมหานคร ...      TH
#
#                     จังหวัด         เขต/อำเภอ  รหัสไปรษณีย์ ประเภทคำสั่งซื้อ  \
# 0             จังหวัดชลบุรี     อำเภอพนัสนิคม         20140              NaN
# 1             จังหวัดภูเก็ต  อำเภอเมืองภูเก็ต         83000              NaN
# 2    จังหวัดประจวบคีรีขันธ์     อำเภอบางสะพาน         77230              NaN
# 3         จังหวัดนครราชสีมา       อำเภอสีคิ้ว         30140              NaN
# 4              จังหวัดสงขลา   อำเภอเมืองสงขลา         90000              NaN
# ..                      ...               ...           ...              ...
# 488    จังหวัดกรุงเทพมหานคร     เขตบางกอกใหญ่         10600              NaN
# 489        จังหวัดบุรีรัมย์      อำเภอนาโพธิ์         31230              NaN
# 490         จังหวัดเชียงราย     อำเภอเชียงของ         57140              NaN
# 491    จังหวัดกรุงเทพมหานคร         เขตพระนคร         10200              NaN
# 492    จังหวัดกรุงเทพมหานคร        เขตมีนบุรี         10510              NaN
#
#      เวลาที่ทำการสั่งซื้อสำเร็จ บันทึก
# 0           2022-05-06 14:02:00    NaN
# 1                           NaT    NaN
# 2                           NaT    NaN
# 3           2022-05-06 15:22:00    NaN
# 4           2022-05-11 11:39:00    NaN
# ..                          ...    ...
# 488                         NaT    NaN
# 489                         NaT    NaN
# 490                         NaT    NaN
# 491                         NaT    NaN
# 492                         NaT    NaN
#
# [493 rows x 54 columns]

# %%
data.to_excel('all.xlsx', encoding='utf-8')
